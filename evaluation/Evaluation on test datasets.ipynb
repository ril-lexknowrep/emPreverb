# %%
import re

test_set_doc = 'validate.txt'
test_set_doc_checked = test_set_doc + '.checked'

# %% [markdown]
# ## Step 1: Load test set

# %%
test_items = []

with open(test_set_doc, encoding='utf-8') as infile:
    for line in infile:
        if not '\t' in line:
            continue
        test_items.append(line.strip().split('\t')[1].strip())

print(f'Loaded {len(test_items)} lines')
# Out:
# Loaded 199 lines

# %% [markdown]
# Test set annotation:
# - Preverb marked by a suffixed backslash followed by an ID number, e.g. `meg\1`
# - Word from which the preverb was separated marked by a pipe followed by the same ID number, e.g. `főzve|1`
# - Within the same line, different verb-prefix pairs must (obviously) receive different ID numbers.
# - Only single-digit ID numbers allowed.
# - A preverb that is not separated from any word in the sentence (ellipsis etc.) is marked with a zero ID:
#     * `"Hazakísérhetlek?" "Meg\0 hát."`
# - Any number of preverbs can have the 0 ID within the same line.
# - A verb directly followed by preverb is only annotated if the preverb is not separated from the preceding verb:
#     * `főzte meg`
#     * but: `főzte|1 volna meg\1`
# - Normally there is a 1:1 correspondence between preverbs and verbs. However, there are exceptions, and these are annotated accordingly, e.g. `Se ki\1, se be\1 nem lehetett menni|1 Budakesziről`; `át-\1 meg átjárták|1`

# %% [markdown]
# ## Step 2: Check test set for errors and reformat for emtsv tok

# %%
with open(test_set_doc_checked, 'w', encoding='utf-8') as outfile:
    for t in test_items:
        prev_indices = re.findall(r'\\([1-5])', t)
        if prev_indices is None:
            print("No prevs:", t) # unannotated line
            continue
        verb_indices = re.findall(r'\|([1-5])', t)
        if (sorted(list(set(prev_indices))) != sorted(prev_indices) or # any duplicate indices
            sorted(list(set(verb_indices))) != sorted(verb_indices) or
            sorted(prev_indices) != sorted(verb_indices) # any unmatched indices
           ):
            print('Possible error:', t)
            print(prev_indices)
            print(verb_indices)
        t = re.sub(r'(\\|\|)(\d)(\S)', r'\1\2 \3', t)
        outfile.write(t.replace('\\', '_p').replace('|', '_v') + '\n')
# Out:
# Possible error: S így búslakodván érzetem csapkodásaiban, kedves anyám jutott eszembe, s el\1 is gondoltam|1, hogy bezzeg az ő kies kertjében más gyümölcs termik; s el\1 azt is, hogy az a gyümölcs most jobb volna nekem, mert anyám nem azt akarná, hogy én álljak helyt a bajban, hanem azt inkább, hogy az öröm állja meg mellettem a helyét.
# ['1', '1']
# ['1']

# %% [markdown]
# If there are errors, correct in input file, then back to step 1.

# %% [markdown]
# ## Step 3: Tokenize in emtsv, insert testid column, run morph,pos

# %%
# !cat {test_set_doc_checked} | docker run -i mtaril/emtsv tok > tok_output.txt

print("tok_output done")

with open('tok_output.txt', encoding='utf-8') as infile:
    with open('morph_input.txt', 'w', encoding='utf-8') as outfile:
        outfile.write(next(infile).strip() + '\ttestid\n')
        for line in infile:
            if line.strip() == '':
                outfile.write(line)
                continue
            testid = '.' # avoid removal of empty column by xtsv
            m = re.findall('_([pv]\d)', line)
            if m:
                testid = m[0]
                line = re.sub('_[pv]\d', '', line)
            outfile.write(line.strip() + '\t' + testid + '\n')

print("morph_input done")

# !cat morph_input.txt | docker run -i mtaril/emtsv morph,pos > pos_output.txt

print("pos_output done")
# Out:
# tok_output done
# morph_input done
# pos_output done

# %%
import sys
sys.path.append('../preverb')
from word import Word

# %% [markdown]
# ## Step 4: Check if preverbs are annotated as preverbs and verb-like tokens as verbs

# %%
from word import Word

with open('pos_output.txt', encoding='utf-8') as infile:
    header = next(infile)
    Word.features = header.strip().split('\t')
    for n, line in enumerate(infile):
        if line.strip() == '':
            continue
        token = Word(line.strip().split('\t'))
        if token.testid[0] == 'p' and not token.xpostag.startswith('[/Prev]'):
            print(f"Bad prev on line {n + 2}:", token, '\n')
        if token.testid[0] == 'v' and not token.xpostag.startswith('[/V]'):
            print(f"Bad verb (?) on line {n + 2}:", token, '\n')
# Out:
# Bad verb (?) on line 760: fogadható	" "	v1	[{"lemma": "fogadható", "tag": "[/Adj][Nom]", "morphana": "fogad[/V]=fogad+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "fogad[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "f:f o:o g:g a:a d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	fogadható	[/Adj][Nom]
#
# Bad verb (?) on line 1146: avatkozás	" "	v1	[{"lemma": "avatkozás", "tag": "[/N][Nom]", "morphana": "avatkozik[/V]=avatkoz+ás[_Ger/N]=ás+[Nom]=", "readable": "avatkozik[/V]=avatkoz + ás[_Ger/N] + [Nom]", "twolevel": "a:a v:v a:a t:t k:k o:o z:z :i :k :[/V] á:á s:s :[_Ger/N] :[Nom]"}]	avatkozás	[/N][Nom]
#
# Bad verb (?) on line 1153: képzelhető	" "	v1	[{"lemma": "képzelhető", "tag": "[/Adj][Nom]", "morphana": "képzel[/V]=képzel+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "képzel[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "k:k é:é p:p z:z e:e l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "képzelhető", "tag": "[/Adj][Nom]", "morphana": "képzelhető[/Adj]=képzelhető+[Nom]=", "readable": "képzelhető[/Adj] + [Nom]", "twolevel": "k:k é:é p:p z:z e:e l:l h:h e:e t:t ő:ő :[/Adj] :[Nom]"}]	képzelhető	[/Adj][Nom]
#
# Bad verb (?) on line 1280: felelő	" "	v1	[{"lemma": "felelő", "tag": "[/Adj][Nom]", "morphana": "felel[/V]=felel+ő[_ImpfPtcp/Adj]=ő+[Nom]=", "readable": "felel[/V] + ő[_ImpfPtcp/Adj] + [Nom]", "twolevel": "f:f e:e l:l e:e l:l :[/V] ő:ő :[_ImpfPtcp/Adj] :[Nom]"}]	felelő	[/Adj][Nom]
#
# Bad verb (?) on line 1298: ítélhető	" "	v2	[{"lemma": "ítélhető", "tag": "[/Adj][Nom]", "morphana": "ítél[/V]=ítél+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "ítél[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "í:í t:t é:é l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	ítélhető	[/Adj][Nom]
#
# Bad verb (?) on line 1397: ébredőnek	" "	v1	[{"lemma": "ébredő", "tag": "[/Adj][Dat]", "morphana": "ébred[/V]=ébred+ő[_ImpfPtcp/Adj]=ő+nek[Dat]=nek", "readable": "ébred[/V] + ő[_ImpfPtcp/Adj] + nek[Dat]", "twolevel": "é:é b:b r:r e:e d:d :[/V] ő:ő :[_ImpfPtcp/Adj] n:n e:e k:k :[Dat]"}, {"lemma": "ébredő", "tag": "[/N][Dat]", "morphana": "ébredő[/N]=ébredő+nek[Dat]=nek", "readable": "ébredő[/N] + nek[Dat]", "twolevel": "é:é b:b r:r e:e d:d ő:ő :[/N] n:n e:e k:k :[Dat]"}]	ébredő	[/Adj][Dat]
#
# Bad verb (?) on line 1451: foghatók	" "	v1	[{"lemma": "fogható", "tag": "[/Adj][Pl][Nom]", "morphana": "fog[/N]=fog+hat[/V]=hat+ó[_ImpfPtcp/Adj]=ó+k[Pl]=k+[Nom]=", "readable": "fog[/N] + hat[/V] + ó[_ImpfPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "f:f o:o g:g :[/N] h:h a:a t:t :[/V] ó:ó :[_ImpfPtcp/Adj] k:k :[Pl] :[Nom]"}, {"lemma": "fogható", "tag": "[/Adj][Pl][Nom]", "morphana": "fog[/V]=fog+ható[_ModPtcp/Adj]=ható+k[Pl]=k+[Nom]=", "readable": "fog[/V] + ható[_ModPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "f:f o:o g:g :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] k:k :[Pl] :[Nom]"}, {"lemma": "fogható", "tag": "[/Adj][Pl][Nom]", "morphana": "fogható[/Adj]=fogható+k[Pl]=k+[Nom]=", "readable": "fogható[/Adj] + k[Pl] + [Nom]", "twolevel": "f:f o:o g:g h:h a:a t:t ó:ó :[/Adj] k:k :[Pl] :[Nom]"}]	fogható	[/Adj][Pl][Nom]
#
# Bad verb (?) on line 1785: mondható	" "	v1	[{"lemma": "mondható", "tag": "[/Adj][Nom]", "morphana": "mond[/V]=mond+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "mond[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "m:m o:o n:n d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	mondható	[/Adj][Nom]
#
# Bad prev on line 1833: utánam	" "	p1	[{"lemma": "után", "tag": "[/Post][1Sg]", "morphana": "én[/N|Pro]=+után[/Post]=után+am[1Sg]=am", "readable": "én[/N|Pro]= + után[/Post] + am[1Sg]", "twolevel": ":é :n :[/N|Pro] u:u t:t á:á n:n :[/Post] a:a m:m :[ :1 :S :g :]"}]	után	[/Post][1Sg]
#
# Bad verb (?) on line 2123: Indulás	" "	v1	[{"lemma": "indulás", "tag": "[/N][Nom]", "morphana": "indul[/V]=indul+ás[_Ger/N]=ás+[Nom]=", "readable": "indul[/V] + ás[_Ger/N] + [Nom]", "twolevel": "i:i n:n d:d u:u l:l :[/V] á:á s:s :[_Ger/N] :[Nom]"}, {"lemma": "indulás", "tag": "[/N][Nom]", "morphana": "indulás[/N]=indulás+[Nom]=", "readable": "indulás[/N] + [Nom]", "twolevel": "i:i n:n d:d u:u l:l á:á s:s :[/N] :[Nom]"}]	indulás	[/N][Nom]
#
# Bad verb (?) on line 2470: bányászható	" "	v1	[{"lemma": "bányászható", "tag": "[/Adj][Nom]", "morphana": "bány<a>ász[/N]=bányász+hat[/V]=hat+ó[_ImpfPtcp/Adj]=ó+[Nom]=", "readable": "bány<a>ász[/N]=bányász + hat[/V] + ó[_ImpfPtcp/Adj] + [Nom]", "twolevel": "b:b á:á n:n y:y á:< s:a z:> :á :s :z :[/N] h:h a:a t:t :[/V] ó:ó :[_ImpfPtcp/Adj] :[Nom]"}, {"lemma": "bányászható", "tag": "[/Adj][Nom]", "morphana": "bányászik[/V]=bányász+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "bányászik[/V]=bányász + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "b:b á:á n:n y:y á:á s:s z:z :i :k :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	bányászható	[/Adj][Nom]
#
# Bad verb (?) on line 3268: érhető	" "	v1	[{"lemma": "érhető", "tag": "[/Adj][Nom]", "morphana": "ér[/V]=ér+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "ér[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é r:r :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "érhető", "tag": "[/Adj][Nom]", "morphana": "érik[/V]=ér+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "érik[/V]=ér + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é r:r :i :k :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	érhető	[/Adj][Nom]
#
# Bad verb (?) on line 4381: adhatók	" "	v1	[{"lemma": "adható", "tag": "[/Adj][Pl][Nom]", "morphana": "ad[/V]=ad+ható[_ModPtcp/Adj]=ható+k[Pl]=k+[Nom]=", "readable": "ad[/V] + ható[_ModPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "a:a d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] k:k :[Pl] :[Nom]"}]	adható	[/Adj][Pl][Nom]
#
# Bad verb (?) on line 4509: emelhető	" "	v1	[{"lemma": "emelhető", "tag": "[/Adj][Nom]", "morphana": "emel[/V]=emel+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "emel[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "e:e m:m e:e l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	emelhető	[/Adj][Nom]
#
# Bad verb (?) on line 4783: küldött	" "	v1	[{"lemma": "küld", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "küld[/V]=küld+ött[Pst.NDef.3Sg]=ött", "readable": "küld[/V] + ött[Pst.NDef.3Sg]", "twolevel": "k:k ü:ü l:l d:d :[/V] ö:ö t:t t:t :[Pst.NDef.3Sg]"}, {"lemma": "küldött", "tag": "[/Adj][Nom]", "morphana": "küld[/V]=küld+ött[_PerfPtcp/Adj]=ött+[Nom]=", "readable": "küld[/V] + ött[_PerfPtcp/Adj] + [Nom]", "twolevel": "k:k ü:ü l:l d:d :[/V] ö:ö t:t t:t :[_PerfPtcp/Adj] :[Nom]"}, {"lemma": "küldött", "tag": "[/Adj][Nom]", "morphana": "küldött[/Adj]=küldött+[Nom]=", "readable": "küldött[/Adj] + [Nom]", "twolevel": "k:k ü:ü l:l d:d ö:ö t:t t:t :[/Adj] :[Nom]"}, {"lemma": "küldött", "tag": "[/N][Nom]", "morphana": "küldött[/N]=küldött+[Nom]=", "readable": "küldött[/N] + [Nom]", "twolevel": "k:k ü:ü l:l d:d ö:ö t:t t:t :[/N] :[Nom]"}]	küldött	[/Adj][Nom]
#
# Bad verb (?) on line 5041: zárva	" "	v1	[{"lemma": "zár", "tag": "[/V][_AdvPtcp/Adv]", "morphana": "zár[/V]=zár+va[_AdvPtcp/Adv]=va", "readable": "zár[/V] + va[_AdvPtcp/Adv]", "twolevel": "z:z á:á r:r :[/V] v:v a:a :[_AdvPtcp/Adv]"}, {"lemma": "zárva", "tag": "[/Adv]", "morphana": "zárva[/Adv]=zárva", "readable": "zárva[/Adv]", "twolevel": "z:z á:á r:r v:v a:a :[/Adv]"}]	zárva	[/Adv]
#
# Bad verb (?) on line 5120: használható	" "	v1	[{"lemma": "használható", "tag": "[/Adj][Nom]", "morphana": "használ[/V]=használ+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "használ[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "h:h a:a s:s z:z n:n á:á l:l :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "használható", "tag": "[/Adj][Nom]", "morphana": "használható[/Adj]=használható+[Nom]=", "readable": "használható[/Adj] + [Nom]", "twolevel": "h:h a:a s:s z:z n:n á:á l:l h:h a:a t:t ó:ó :[/Adj] :[Nom]"}]	használható	[/Adj][Nom]
#
# Bad verb (?) on line 5174: valósítható	" "	v1	[{"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "való[/Adj]=való+sít[_AdjVbz_Tr/V]=sít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "való[/Adj] + sít[_AdjVbz_Tr/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó :[/Adj] s:s í:í t:t :[_AdjVbz_Tr/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "való[/N]=való+s[_Adjz:s/Adj]=s+ít[_AdjVbz_Tr/V]=ít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "való[/N] + s[_Adjz:s/Adj] + ít[_AdjVbz_Tr/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó :[/N] s:s :[_Adjz:s/Adj] í:í t:t :[_AdjVbz_Tr/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "valós[/Adj]=valós+ít[_AdjVbz_Tr/V]=ít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "valós[/Adj] + ít[_AdjVbz_Tr/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó s:s :[/Adj] í:í t:t :[_AdjVbz_Tr/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "valósít[/V]=valósít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "valósít[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó s:s í:í t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	valósítható	[/Adj][Nom]
#
# Bad verb (?) on line 5228: válthatók	" "	v1	[{"lemma": "váltható", "tag": "[/Adj][Pl][Nom]", "morphana": "vált[/V]=vált+ható[_ModPtcp/Adj]=ható+k[Pl]=k+[Nom]=", "readable": "vált[/V] + ható[_ModPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "v:v á:á l:l t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] k:k :[Pl] :[Nom]"}]	váltható	[/Adj][Pl][Nom]
#
# Bad verb (?) on line 5292: fordult	" "	v1	[{"lemma": "fordul", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "fordul[/V]=fordul+t[Pst.NDef.3Sg]=t", "readable": "fordul[/V] + t[Pst.NDef.3Sg]", "twolevel": "f:f o:o r:r d:d u:u l:l :[/V] t:t :[Pst.NDef.3Sg]"}, {"lemma": "fordult", "tag": "[/Adj][Nom]", "morphana": "fordul[/V]=fordul+t[_PerfPtcp/Adj]=t+[Nom]=", "readable": "fordul[/V] + t[_PerfPtcp/Adj] + [Nom]", "twolevel": "f:f o:o r:r d:d u:u l:l :[/V] t:t :[_PerfPtcp/Adj] :[Nom]"}]	fordult	[/Adj][Nom]
#
# Bad verb (?) on line 5635: térítendő	" "	v2	[{"lemma": "térítendő", "tag": "[/Adj][Nom]", "morphana": "térít[/V]=térít+endő[_FutPtcp/Adj]=endő+[Nom]=", "readable": "térít[/V] + endő[_FutPtcp/Adj] + [Nom]", "twolevel": "t:t é:é r:r í:í t:t :[/V] e:e n:n d:d ő:ő :[_FutPtcp/Adj] :[Nom]"}]	térítendő	[/Adj][Nom]
#
# Bad verb (?) on line 5663: térítendő	" "	v3	[{"lemma": "térítendő", "tag": "[/Adj][Nom]", "morphana": "térít[/V]=térít+endő[_FutPtcp/Adj]=endő+[Nom]=", "readable": "térít[/V] + endő[_FutPtcp/Adj] + [Nom]", "twolevel": "t:t é:é r:r í:í t:t :[/V] e:e n:n d:d ő:ő :[_FutPtcp/Adj] :[Nom]"}]	térítendő	[/Adj][Nom]

# %% [markdown]
# If there is any output, the line numbers refer to `pos_output.txt`.
#
# Check whether tokens annotated as separated preverbs are also analysed by morph,pos as preverbs. If not (e.g. if the preverb _meg_ is tagged by emtsv as a `[/Conj]`), **remove this annotation** (or the whole item if no annotation left) from the test set because `preverb` will necessarily fail due to incorrect emtsv annotation, which is extraneous to its performance evaluation.
#
# Exception: person-inflected preverb-like postpositions such as in `utánam\1 dobják|1`, which are tagged by emtsv as `[/Post]`, and case-inflected personal pronouns such as in `hozzá\1 voltam szokva|1`, which are tagged as `[/N|Pro]`, **should not be removed from the test set** since `preverb` should be able to handle these.
#
# If a token is annotated as the verb stem counterpart of a separated preverb, but is not tagged by emtsv as a verb, check whether the preverb annotation is correct, but if so, **do not remove this annotation** from the test set. `preverb` is supposed to be able to handle the connection of such separated preverbs.
#
# After all real errors have been corrected, rerun everything from step 1.

# %%
# !cat pos_output.txt | python ../preverb > preverb_output.tsv

# %% [markdown]
# ## Step 5: Verify diffs

# %% [markdown]
# NB: ONLY DO THIS ON THE VALIDATION DATASET.

# %%
def print_error(error_str, n, token):
    print(error_str, f"on token {n + 2}: {token.form}")

with open('preverb_output.tsv', encoding='utf-8') as infile:
    header = next(infile)
    Word.features = header.strip().split('\t')
    curr_sent = ''
    testid_to_previd = {}
    annotated_previds = {}
    irrelevant_previds = {}
    bad_flag = False
    for n, token in enumerate(infile):
        if token.strip() == '':
            if bad_flag:
                print(curr_sent, "\n")
            curr_sent = ''
            bad_flag = False
            testid_to_previd = {}
            annotated_previds = {}
            irrelevant_previds = {}
            continue
        token = Word(token.strip('\n').split('\t'))
        token_suffix = token.testid
        if token_suffix == '.':
            token_suffix = ''
        else:
            token_suffix = '_' + token_suffix
        curr_sent += token.form + token_suffix + token.wsafter.replace('"','')
        
        if token.testid == 'p0':
            if token.separated == 'conn':
                print_error("Incorrectly connected preverb", n, token)
            continue
        
        if token.testid[0] == 'p' and not token.separated == 'conn':
            print_error("Preverb mismatch", n, token)
            bad_flag = True
            continue
        elif token.testid[0] == 'v' and not token.separated == 'sep':
            print_error("Verb mismatch", n, token)
            bad_flag = True
            continue
        elif token.testid == '.' and token.previd != '':
            if token.previd in annotated_previds:
                print_error("Unannotated token connected to annotated", n, token)
                print(f"Incorrectly connected to {annotated_previds[token.previd]}")
                bad_flag = True
            else:
                irrelevant_previds[token.previd] = token.form
            continue
        elif token.previd == '':
            continue

        if token.previd in irrelevant_previds:
            print_error("Annotated token connected to unannotated", n, token)
            print(f"Incorrectly connected to {irrelevant_previds[token.previd]}")
            bad_flag = True
        elif token.testid[1] not in testid_to_previd:
            testid_to_previd[token.testid[1]] = token.previd
            annotated_previds[token.previd] = token.form
        elif testid_to_previd[token.testid[1]] != token.previd:
            print_error("Annotated token index mismatch", n, token)
            bad_flag = True
# Out:
# Unannotated token connected to annotated on token 21: van
# Incorrectly connected to le
# Verb mismatch on token 22: írva
# S le_p1 is van írva_v1 .\n
#
# Preverb mismatch on token 294: el
# Verb mismatch on token 299: mondani
# Akkor Fehérlófia önkéntelenül magához ölelte És mintha nem is ő tenné megcsókolta Krisztina száját Sután ügyetlenül mert összekoccant a foguk Rögtön elengedte hátra_p1 is lépett_v1 tőle Zavarában el_p2 sem búcsúzott_v2 szaladt vissza_p3 se nézve_v3 Megcsókoltam ismételte ujjongva magában Megcsókoltam igen itt maradunk a hazában Együtt a hazában édes vagy édes édes\nEzt persze el_p4 lehetne nem-költői módon is mondani_v4 , de mennyivel nagyobb dolog, ha ez költői megfogalmazást kap.
#
# Preverb mismatch on token 382: Be
# Verb mismatch on token 385: durrantani
# Be_p1 lehetett volna durrantani_v1 a vendégek fogadására szánt szobába.\n
#
# Verb mismatch on token 585: Fölidézte
# Preverb mismatch on token 603: föl
# Verb mismatch on token 637: mondott
# Preverb mismatch on token 639: el
# Preverb mismatch on token 647: át-
# Verb mismatch on token 649: átjárták
# Fölidézte_v1 magában Veron jobbjának barátságos szorítását, hangjának zengését, derűs szemének biztató csillámát és jó mosolyát, föl_p1 a mély beszélgetéseket, amikor már azt hitte István, elmondott mindent, s Veron halkan kérdezni kezdett, aprók, szinte tőmondatosak voltak a kérdései, amelyekből azonban kiderült, hogy mégse mondott_v2 István el_p2 mindent, a kérdések s megjegyzések szavai át-_p3 meg átjárták_v3 az elmondottak homályos zugait, s aztán Veron magyarázni kezdett, megmagyarázta: mit látott István, és miért látta, amit látott, olyannak, amilyennek.\n
#
# Verb mismatch on token 760: fogadható
# Preverb mismatch on token 761: el
# Sz.: Engem azért egy kicsit megrázott előbb, amikor azt mondta, hogy a pszichológiai bizonyítás annak ellenében, hogy Petőfi Szibériában nyugodnék, nem fogadható_v1 el_p1 .\n
#
# Preverb mismatch on token 882: Meg
# Verb mismatch on token 885: hallani
# Meg_p1 kell végre hallani_v1 a kor szavát, Fokos kolléga!\n
#
# Preverb mismatch on token 1144: be
# Verb mismatch on token 1146: avatkozás
# Vegye meg ezt, Ferdi bácsi - húzta ki Ildi a hóna alól, hogy odamutassa, Nadragulyevác Szávó üstökös életű költőnk örök érvényű tankölteményeinek öt egyforma kötetét, és elé nyújtotta, futószalagon (Aranyos Reske csak távolabbi szemlélője volt a jelenetnek, a be_p1 nem avatkozás_v1 elve alapján).\n
#
# Verb mismatch on token 1153: képzelhető
# Preverb mismatch on token 1154: el
# Nehezen képzelhető_v1 el_p1 ; de akkor is, mi volt a formája?\n
#
# Preverb mismatch on token 1278: meg
# Verb mismatch on token 1280: felelő
# Preverb mismatch on token 1296: el
# Verb mismatch on token 1298: ítélhető
# Egyik-másik annyi tiszteletlenséget, izgatást, szemérmetlen (a való tényeknek egyáltalában meg_p1 nem felelő_v1 ) önleleplezést tartalmazott, hogy ezekért nem is vállalhattam a felelősséget egy olyan, eléggé el_p2 nem ítélhető_v2 jogrendszerben, amely ilyesmiért nem a korszellem és az örök szellem közös leányát, a Múzsát, hanem bűnös hanyagsággal a költőt vonja perbe.\n
#
# Unannotated token connected to annotated on token 1353: tudják
# Incorrectly connected to el
# Verb mismatch on token 1354: képzelni
# Egy portugál bölcselő szerint, ha egy rétegtől munkaerőt, terményt, mindent olcsón meg_p1 lehet kapni_v1 , a vásárlók eszmevilága szükségszerűen úgy alakul, hogy el_p2 sem tudják képzelni_v2 : rendkívülinek, sőt afféle szerződésszegésnek érzik, ha valami mégsem olcsó, vagy kiváltképp nem kapható.\n
#
# Preverb mismatch on token 1395: fel
# Verb mismatch on token 1397: ébredőnek
# Ti fogjátok tudtául adni, hogy Kolozsvár felett zivatar vonul, s nedveteknek hirtelen újjáéledése jelenti meg a mélyen alvónak és fel_p1 nem ébredőnek_v1 az újdonatúj tavaszt.\n
#
# Preverb mismatch on token 1449: fel
# Verb mismatch on token 1451: foghatók
# Mintha valakiket megleptem volna itt, kik test szerint bár láthatatlanok, azóta súlyosabban itt lakoznak, mióta szemmel fel_p1 nem foghatók_v1 .\n
#
# Unannotated token connected to annotated on token 1655: lett
# Incorrectly connected to meg
# Verb mismatch on token 1657: fagyva
# Hol elöl, hol hátul ültek egyre többen, s a hó nőtt akkorára, hogy ha meg_p1 nem lett volna fagyva_v1 , ki_p2 sem látszik_v2 belőle az ember.\n
#
# Preverb mismatch on token 1741: el
# Verb mismatch on token 1744: mondanom
# Aztán el_p1 kellett még mondanom_v1 az öregasszonynak: - Együtt voltunk - magyarázkodnom: - Zeitzban -, s valahogyan szigorú, már-már számon kérő kérdésére: - És miért nem együtt jöttek haza? - mentegetőznöm szinte: - Elváltunk.\n
#
# Preverb mismatch on token 1783: ki
# Verb mismatch on token 1785: mondható
# A ki_p1 nem mondható_v1 , de a társadalomban még élő igazság és jogérzet, a cselekvésre sarkalló akarat, az éber lelkiismeret jelenik meg velük a színen.\n
#
# Preverb mismatch on token 1833: utánam
# Verb mismatch on token 1834: dobják
# Pedig a többiek már trappolnak is az emeletről, hogy újra utánam_p1 dobják_v1 , mert dühük már fáj: csak annyit éreznek, hogy mekkora feszültség van egy mozdulatlanul álló szörnyű nagy kőtömbben.\n
#
# Verb mismatch on token 2044: törülné
# Preverb mismatch on token 2046: el
# Verb mismatch on token 2057: visszamutat
# Preverb mismatch on token 2065: vissza
# Vajon nem törülné_v1 -e el_p1 azt a magabiztos mozdulatát, mellyel a XX. századi Csák visszamutat_v2 ma a dunántúli város középkori történetére, vissza_p2 a ködszerű múltra.\n
#
# Preverb mismatch on token 2117: ketté
# Verb mismatch on token 2118: hasadnak
# Szeretsz?? kérdeztem a lánytól s vártam, hogy mondjon valamit, amitől ketté_p1 hasadnak_v1 a falak.\n
#
# Verb mismatch on token 2123: Indulás
# Preverb mismatch on token 2124: haza
# Indulás_v1 haza_p1 !\n
#
# Unannotated token connected to annotated on token 2142: tudja
# Incorrectly connected to El
# Verb mismatch on token 2143: képzelni
# El_p1 se tudja képzelni_v1 , hogy mást is lehet.\n
#
# Verb mismatch on token 2343: várva
# Preverb mismatch on token 2346: meg
# Kuczka és a vele azonos véleményen lévők határozottan állították, hogy az egyetlen lehetséges, kommunista íróhoz méltó magatartás, amely ezentúl a pártot is segíti, az, hogy nyíltan és tisztán megírják tapasztalataikat, feltárják a hibákat, nem várva_v1 most már meg_p1 , amíg megint ellentmond költészetüknek a valóság, nem is szólva arról, amíg megint fejükre koppint a párt is, hogy a nehéz időkben lehunyt szemmel járták a világot.\n
#
# Verb mismatch on token 2470: bányászható
# Preverb mismatch on token 2471: ki
# Teljes objektivitása ugyanis önmagában van, a maga tisztaságában nem bányászható_v1 ki_p1 .\n
#
# Preverb mismatch on token 2728: el
# Verb mismatch on token 2731: végezni
# - Ezt a kísérletet néhány megjelölt úszó fadarabbal is épp ilyen jól el_p1 lehetett volna végezni_v1 - mondja F., a sokat tapasztalt öreg környezetvédő szakember.\n
#
# Verb mismatch on token 3045: csapott
# Preverb mismatch on token 3047: be
# De ezen a csúcson - s ezt már a regény bizonyítja - elkezdtem gyanakodni erre az épségre, a normára: nem csapott_v1 -e be_p1 , nem zárta -e fölpattinthatatlan tokba azt, ami több, nemesebb volt bennem: " az abnormalitásom ".\n
#
# Verb mismatch on token 3268: érhető
# Preverb mismatch on token 3269: el
# A gyógynövény párlat egyik alkotó elemét ma is csak én tudom, a porcelán régi fénye az ismert hőfokon is csak egy bizonyos összetételű mázzal érhető_v1 el_p1 : ennek a titkát sem fedtem föl.\n
#
# Verb mismatch on token 3380: kapja
# Preverb mismatch on token 3382: meg
# Nehezen tudom elképzelni, hogy apám a valamelyik haszonleső maffiózó által elétárt Porhüvelyt ne vizsgálta_v1 volna meg_p1 alaposan, valóban azt kapja_v2 -e meg_p2 , amit áhít.\n
#
# Verb mismatch on token 3543: bújt
# Preverb mismatch on token 3546: be
# "\nHogy menekűlt az a réműlt kukac, mikor szétbuggyantottad rejtekét! hogy bújt, vissza, az eltűnt éjbe! még beljebb, a mag alá! hogy bújt_v1 csupasz titka be_p1 a takaró húsba, az áldott édenbe, a biztosba!...
#
# Preverb mismatch on token 4012: el
# S így búslakodván érzetem csapkodásaiban, kedves anyám jutott eszembe, s el_p1 is gondoltam_v1 , hogy bezzeg az ő kies kertjében más gyümölcs termik; s el_p1 azt is, hogy az a gyümölcs most jobb volna nekem, mert anyám nem azt akarná, hogy én álljak helyt a bajban, hanem azt inkább, hogy az öröm állja meg mellettem a helyét.\n
#
# Verb mismatch on token 4164: kapja
# Preverb mismatch on token 4167: el
# De Jucika riadtan kapja_v1 a kezét el_p1 .\n
#
# Verb mismatch on token 4381: adhatók
# Preverb mismatch on token 4382: ki
# [2] Az idegen állampolgárok és a hontalanok csakis valamely nemzetközi megállapodás alapján vagy a kölcsönösség feltételei között adhatók_v1 ki_p1 .\n
#
# Verb mismatch on token 4509: emelhető
# Preverb mismatch on token 4510: ki
# Sokszor mereven értelmezték, adott esetben a gyermek ellen fordították azokban azt a gyermekvédelmi törvényben deklarált elvet is, amely szerint " szociális okból gyermek nem emelhető_v1 ki_p1 a családból ".\n
#
# Verb mismatch on token 4742: teszi
# Preverb mismatch on token 4744: meg
# Azt, hogy mi módon teszi_v1 ezt meg_p1 a koalíció vagy mi módon nem, azzal van, amikor egyetértünk, és van, amikor nem.\n
#
# Preverb mismatch on token 4781: ki
# Verb mismatch on token 4783: küldött
# Kettő: ha arra gondolna, amire elvileg gondolhatna egy teljesen más tényállás esetén, a ki_p1 nem küldött_v1 anyag napirendre vételéről, az most nem áll fenn.\n
#
# Preverb mismatch on token 4916: el
# Verb mismatch on token 4920: hárítsak
# Egyet nagyon határozottan el_p1 kell, hogy hárítsak_v1 : akkor mi nem tartoztunk a kormányzó pártok közé.\n
#
# Unannotated token connected to annotated on token 5028: tudni
# Incorrectly connected to el
# Verb mismatch on token 5029: készülni
# "\nEl_p2 tud készülni_v2 , egy ekkora létesítménynek egy hónap alatt el_p1 kell tudni készülni_v1 .\n
#
# Preverb mismatch on token 5039: le
# Verb mismatch on token 5041: zárva
# (Marsi Péter Pál: Miért, le_p1 van zárva_v1 a vita?)\n
#
# Verb mismatch on token 5093: kerül
# Preverb mismatch on token 5095: be
# Ha azt mondom, hogy 2-300 milliárd beruházásigényről van szó, és ehhez képest 3 milliárd kerül_v1 ide be_p1 , akkor azt kell mondjam, hogy az aránytalan, ez így hiba.\n
#
# Verb mismatch on token 5120: használható
# Preverb mismatch on token 5121: fel
# Az elnyert támogatás kizárólag a tárgyévben meghirdetett tervpályázatok céljára használható_v1 fel_p1 .\n* Vissza_p0 a tartalomjegyzékhez\nÚ vissza_p0 a címlaphoz\n(1) Minden sírhelytábla számát jelzőoszlopon, a sírhelysorok és sírhelyek számát pedig a sorokon túl jól látható helyen fel_p1 kell tüntetni_v1 .\n
#
# Verb mismatch on token 5174: valósítható
# Preverb mismatch on token 5175: meg
# Az erőmű építés vonatkozásában megvizsgálandó annak lehetősége is, hogy a beruházás több lépcsőben, 3 év alatt hogyan valósítható_v1 meg_p1 :\nA felsorolt megoldásoknak meg_p1 kell felelni_v1 a mindenkor érvényes forgalmi rend kialakítására vonatkozó jogszabálynak.\n
#
# Preverb mismatch on token 5226: vissza
# Verb mismatch on token 5228: válthatók
# (11) A vonaljegyek vissza_p1 nem válthatók_v1 .\n
#
# Preverb mismatch on token 5290: elő
# Verb mismatch on token 5292: fordult
# A történelemben eddig elő_p1 nem fordult_v1 feladatok elé kerültünk, és ennek is viseljük gondokat okozó terhét.\n
#
# Preverb mismatch on token 5521: rá
# Verb mismatch on token 5524: mutatnom
# Ugyanakkor rá_p1 kell arra mutatnom_v1 , hogy - a háromoldalú tárgyalásokat is beleszámítva, amelyek közismerten 1989-ben történtek - most már nyolc éve folyik az egész jogrendünk átalakítása, és bizony megítélésem szerint ennek a nyolc évnek bőségesen elegendőnek kellett volna lennie ahhoz, hogy egy új büntetőkódex kerüljön megalkotásra.\n
#
# Preverb mismatch on token 5633: vissza
# Verb mismatch on token 5635: térítendő
# Preverb mismatch on token 5661: vissza
# Verb mismatch on token 5663: térítendő
# Most közlöm önnel, az eddigi 50 százalékos fogyasztásiadó-visszatérítés, ami a gázolajba be_p1 volt építve_v1 , most 70 százalékosra emelkedett fel 1996. január 1-jétől; gépek beszerzéséhez és vásárlásához 25 százalék vissza_p2 nem térítendő_v2 támogatást biztosítunk; beruházásokhoz, építményekhez fix összegű támogatást adunk, ami négyzetméterenként négyezertől nyolcezer forintig terjedhet, és ez - még egyszer mondom - vissza_p3 nem térítendő_v3 támogatás.\n

# %% [markdown]
# ## Step 6: Calculate evaluation metrics

# %%
# A debuggal sorok csak debugoláshoz / átláthatósághoz kellenek, és törölhetők, ha minden jó így.

preverb_count, true_pos, false_pos, true_neg, false_neg = 0, 0, 0, 0, 0

with open('validate_baseline_output.tsv', encoding='utf-8') as infile:
    header = next(infile)
    Word.features = header.strip().split('\t')

    curr_sent = '' # debug

    p_testids = {}
    v_testids = {}
    irrelevant_previds = []

    for n, token in enumerate(infile):
        if token.strip() == '':
            for p_testid, p_previd in p_testids.items():
                if (p_previd in irrelevant_previds or  # \i is connected to a non-annotated verb
                    p_testid not in v_testids or       # \i is not connected to any annotated verbs
                    v_testids[p_testid] != p_previd):  # \i is not connected to |i, but some other |j
                    false_pos += 1
                    print("False pos", p_testid) # debug
                else: 
                    true_pos += 1
                    print("True pos", p_testid) # debug
            print(curr_sent)  # debug
            print("P:", p_testids) # debug
            print("V:", v_testids) # debug
            print("Irrel:", irrelevant_previds) # debug
            curr_sent = '' # debug
            p_testids = {}
            v_testids = {}
            irrelevant_previds = []
            print() # debug
            continue
        
        token = Word(token.strip('\n').split('\t'))
        token_suffix = token.testid # debug
        if token_suffix == '.': # debug
            token_suffix = '' # debug
        else: # debug
            token_suffix = '_' + token_suffix # debug
        curr_sent += token.form + token_suffix + token.wsafter.replace('"','') # debug
        
        if token.testid == '.':
            if token.previd != '':
                irrelevant_previds.append(token.previd)
            continue

        if token.testid == 'p0':
            preverb_count += 1
            if token.separated == 'conn':
                false_pos += 1   # preverb annotated as \0 connected to anything
                print("False pos") # debug
            else:
                true_neg += 1    # not connected, OK
                print("True neg") # debug
            continue
        
        if token.testid[0] == 'p':
            preverb_count += 1
            if token.separated != 'conn':
                false_neg += 1   # preverb annotated as \1 etc. should have been connected
                print("False neg", token.testid[1:]) # debug
            elif token.testid[1] in p_testids and p_testids[token.testid[1]] != token.previd:
                false_pos += 1   # previd does not match preverb with the same annotation
                print("False pos", token.testid[1:]) # debug
            else:
                p_testids[token.testid[1:]] = token.previd
            continue

        if token.testid[0] == 'v' and token.separated == 'sep':
            v_testids[token.testid[1:]] = token.previd        

print(preverb_count) # debug
print([true_pos, false_pos, true_neg, false_neg]) # debug
assert preverb_count == sum([true_pos, false_pos, true_neg, false_neg]) # debug
# Out:
# True pos 1
# True pos 2
# Be_p1 fog következni_v1, mert be_p2 kell következzék_v2 az immár elkerülhetetlen totális civilizációs összeomlás.\n
# P: {'1': '1', '2': '2'}
# V: {'1': '1', '2': '2'}
# Irrel: []
#
# False pos 3
# S le_p3 is van írva_v3.\n
# P: {'3': '3'}
# V: {}
# Irrel: ['3']
#
# True pos 4
# Jaj, annyi a gondom, hogy ki_p4 sem látszom_v4 belőle.\n
# P: {'4': '4'}
# V: {'4': '4'}
# Irrel: []
#
# True pos 5
# True pos 6
# Idő kérdése, de törvényszerűen alakul_v5 majd ki_p5 végül az a bizonyos új istenű és új módon értelmes világ, aminek el_p6 kell jönnie_v6...\n
# P: {'5': '5', '6': '6'}
# V: {'5': '5', '6': '6'}
# Irrel: []
#
# True pos 7
# Menne ő is szívesen (miként azt később meg_p7 is teszi_v7), de egyelőre még szerve zési feladatai vannak.\n
# P: {'7': '7'}
# V: {'7': '7'}
# Irrel: []
#
# True pos 8
# A nézőt valahogy meg_p8 kell tartani_v8.\n
# P: {'8': '8'}
# V: {'8': '8'}
# Irrel: []
#
# True pos 9
# Melyhez mintha már hozzá_p9 is szoktunk_v9 volna, mely nélkül mintha már létezni sem tudnánk.\n
# P: {'9': '9'}
# V: {'9': '9'}
# Irrel: []
#
# True pos 10
# Mondták, hogy meg_p10 van igézve_v10.\n
# P: {'10': '10'}
# V: {'10': '10'}
# Irrel: []
#
# True pos 11
# Előbb a kapuig mehettem el vele, majd később be_p11 is invitált_v11.\n
# P: {'11': '12'}
# V: {'11': '12'}
# Irrel: ['11', '11']
#
# True pos 12
# - Vagyis valamennyi idegent ebben a faluban sürgősen meg_p12 kell semmisítenünk_v12, még mielőtt észrevennének.\n
# P: {'12': '13'}
# V: {'12': '13'}
# Irrel: []
#
# True pos 13
# És megint csak hosszú ideig nem tartottam lehetségesnek, hogy bekövetkezzék, aminek pedig minden józan emberi számítás szerint be_p13 kellett következnie_v13.\n
# P: {'13': '14'}
# V: {'13': '14'}
# Irrel: []
#
# True pos 14
# True pos 15
# Hatalmasat ugrott előre, egész testével erőlködve, megfeszítve magát, kockáztatva a móka kimenetelét, de be_p14 kellett látnia_v14, hogy most csakugyan nincs menekvés, a csomók szakszerűen, precízen tartják, a játékot végig_p15 kell játszania_v15.\n
# P: {'14': '15', '15': '16'}
# V: {'14': '15', '15': '16'}
# Irrel: []
#
# - Tessék csak papizgatni, kisasszonyka!
# P: {}
# V: {}
# Irrel: []
#
# True pos 16
# Föl_p16 kell épülnie_v16!\n
# P: {'16': '17'}
# V: {'16': '17'}
# Irrel: []
#
# True pos 17
# Nem gazdagít, megdolgoztat, de meg_p17 is adja_v17 az ünnepet.\n
# P: {'17': '18'}
# V: {'17': '18'}
# Irrel: []
#
# False neg 21
# True pos 18
# True pos 19
# True pos 20
# Akkor Fehérlófia önkéntelenül magához ölelte És mintha nem is ő tenné megcsókolta Krisztina száját Sután ügyetlenül mert összekoccant a foguk Rögtön elengedte hátra_p18 is lépett_v18 tőle Zavarában el_p19 sem búcsúzott_v19 szaladt vissza_p20 se nézve_v20 Megcsókoltam ismételte ujjongva magában Megcsókoltam igen itt maradunk a hazában Együtt a hazában édes vagy édes édes\nEzt persze el_p21 lehetne nem-költői módon is mondani_v21, de mennyivel nagyobb dolog, ha ez költői megfogalmazást kap.
# P: {'18': '19', '19': '20', '20': '22'}
# V: {'18': '19', '19': '20', '20': '22'}
# Irrel: ['21']
#
# True pos 22
# "\nOttan aztán meg_p22 sem állva_v22?\n
# P: {'22': '23'}
# V: {'22': '23'}
# Irrel: []
#
# True pos 23
# Akkor most el_p23 fogja kaparni_v23.\n
# P: {'23': '24'}
# V: {'23': '24'}
# Irrel: []
#
# True pos 24
# Továbbá föl_p24 fog kelni_v24 a nap, a fű sárgásan izzani kezd, s a távolban a város fölött, az öttízes és az öthúszas fölött a kéményekből mint távozó nagy halak úsznak elő a koszosabbnál koszosabb lila felhők.\n
# P: {'24': '25'}
# V: {'24': '25'}
# Irrel: ['26', '26']
#
# Nem ártott volna, ha a mészégető pár nappal hamarabb érkezik.
# P: {}
# V: {}
# Irrel: []
#
# False neg 25
# Be_p25 lehetett volna durrantani_v25 a vendégek fogadására szánt szobába.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 26
# Később tudtam_v26 csak meg_p26, hogy a partraszállás óta Playa Giron nem kizárólag fürdőtelep, hanem halászati iskolaközpont is.\n
# P: {'26': '27'}
# V: {'26': '27'}
# Irrel: []
#
# True pos 27
# De a halált - az elnyújtható ravaszkodások ellenére - egyszer mégiscsak be_p27 kellett vallanunk_v27.\n
# P: {'27': '28'}
# V: {'27': '28'}
# Irrel: []
#
# True pos 28
# True pos 29
# Gondoljuk_v28 csak el_p28 - Adyt idézve -, hogy a nagy vallási háborúságok idején Ázsia peremén akadt egy töredék ország, amely ki_p29 merte jelenteni_v29, hogy az embereknek a hite az ő külön dolguk.\n
# P: {'28': '29', '29': '30'}
# V: {'28': '29', '29': '30'}
# Irrel: []
#
# True pos 30
# Az például meg_p30 sem fordult_v30 az agyunkban, hogy százmilliók lelki kiüresedése, elfáradása, undora anélkül is, hogy ennek a folyamatnak neve volna, nagyobb hatású forradalom lehet, mint amilyen a Nagy Októberi volt vagy 1956, illetve 1968.\n
# P: {'30': '31'}
# V: {'30': '31'}
# Irrel: []
#
# True pos 31
# És már húzta_v31 is fel_p31 a gipszlábát.\n
# P: {'31': '32'}
# V: {'31': '32'}
# Irrel: []
#
# True pos 32
# - Meg_p32 akart torolni_v32 valamit, de kizökkentettem a lelki egyensúlyából!\n
# P: {'32': '33'}
# V: {'32': '33'}
# Irrel: []
#
# - Hogy láttad, te locsifecsi?
# P: {}
# V: {}
# Irrel: []
#
# True pos 33
# Be_p33 volt kötve_v33 a szemed!\n
# P: {'33': '34'}
# V: {'33': '34'}
# Irrel: []
#
# True pos 34
# Féltettem is, s ki_p34 akartam vetni_v34 magamból minden mást, szégyenkezve gondoltam apám sokarcú életére...\n
# P: {'34': '35'}
# V: {'34': '35'}
# Irrel: []
#
# True pos 35
# " Mutasd csak a szemüvegedet ", odanyúlt, el_p35 akartam kapni_v35 a fejem, azután mégsem mozdultam.\n
# P: {'35': '36'}
# V: {'35': '36'}
# Irrel: []
#
# False neg 36
# False neg 37
# False neg 38
# Fölidézte_v36 magában Veron jobbjának barátságos szorítását, hangjának zengését, derűs szemének biztató csillámát és jó mosolyát, föl_p36 a mély beszélgetéseket, amikor már azt hitte István, elmondott mindent, s Veron halkan kérdezni kezdett, aprók, szinte tőmondatosak voltak a kérdései, amelyekből azonban kiderült, hogy mégse mondott_v37 István el_p37 mindent, a kérdések s megjegyzések szavai át-_p38 meg átjárták_v38 az elmondottak homályos zugait, s aztán Veron magyarázni kezdett, megmagyarázta: mit látott István, és miért látta, amit látott, olyannak, amilyennek.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 39
# Ilyen szarságért be_p39 nem zárják_v39.\n
# P: {'39': '37'}
# V: {'39': '37'}
# Irrel: []
#
# Lehetne például örülni annak, hogy milyen nagy tisztelői vagyunk a vallásnak, jelen esetben a mohamedán hitnek.
# P: {}
# V: {}
# Irrel: []
#
# True pos 40
# Meg_p40 lehetne kérdezni_v40: egy ország megszállása és önvédelmi harca esetében csakugyan olyan lovagias képlet szerint folyik a játszma, hogy katona áll szemben katonával stb?\n
# P: {'40': '38'}
# V: {'40': '38'}
# Irrel: []
#
# False neg 41
# True pos 42
# Sz.: Engem azért egy kicsit megrázott előbb, amikor azt mondta, hogy a pszichológiai bizonyítás annak ellenében, hogy Petőfi Szibériában nyugodnék, nem fogadható_v41 el._p41\nIlyen elméleti útmutatások birtokában a magyar kommunisták teoretikusai természetesen erélyesen védték a Horthy-rendszerben elnyomott S.-ot, amikor még az is előfordult, hogy Illyés Gyulát egy vagy két napra le_p42 is tartóztatták_v42 izgatás címén.\n
# P: {'42': '39'}
# V: {'42': '39'}
# Irrel: []
#
# True pos 43
# Aki valamely köztársaságot alapít, el_p43 kell rendelnie_v43, hogy szabad legyen bevádolni minden polgárt, minden félelem és gyanakvás nélkül.\n
# P: {'43': '40'}
# V: {'43': '40'}
# Irrel: []
#
# True pos 44
# Rákosiék Marxtól csak annyit vettek át, hogy a kispolgár reakciós - s ennek megfelelően mindent meg_p44 is tettek_v44 annak érdekében, hogy reakcióssá tegyék...\n
# P: {'44': '42'}
# V: {'44': '42'}
# Irrel: ['41', '41']
#
# True pos 45
# Hogy ez tegnap még egy öntelt, ifjú nő volt - s őt búcsúztatják_v45 ma el_p45?\n
# P: {'45': '43'}
# V: {'45': '43'}
# Irrel: []
#
# Érdekes írások voltak ezek, de valahogy hiányzott belőlük a meggyőződés lüktetése.
# P: {}
# V: {}
# Irrel: []
#
# False neg 46
# Meg_p46 kell végre hallani_v46 a kor szavát, Fokos kolléga!\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 47
# Felhívást kell készíteni a Minisztertanács nevében, ezt igen gondosan kell megírni, mint az események utáni első kormánydokumentumot..., mert az egész világ fel_p47 fog figyelni_v47 rá.\n
# P: {'47': '44'}
# V: {'47': '44'}
# Irrel: []
#
# True pos 48
# Pongrácz Gergely aznap érkezett a Corvin közbe, Angyal István még meg_p48 sem alakította_v48 csoportját.\n
# P: {'48': '45'}
# V: {'48': '45'}
# Irrel: []
#
# True neg
# True pos 49
# Taxi, haza, néhány ruhadarab, fogkefe, miegymás, be_p0 a bőröndbe mindent, kezembe az aktatáskát, taxi, rohanok a pályaudvarra, épp hogy elérem a vonatot, a vonat máris indul, mintha csak rám várt volna, nyúlok a zsebembe, rá_p49 akarok gyújtani_v49, erős dohányos vagyok, elnök elvtárs, ez az egyetlen szenvedélyem, nem jó szenvedély, belátom, nem hasznos, de aki annyit dolgozik, mint mi, ezt szokta mondani Kalácska elvtárs, aki annyit dolgozik, az legalább egyetlen szenvedélyt megengedhet magának, hiszen a nép szolgálata nem aszkétákat követel, nem szerzeteseket, ezt már rég túlhaladtuk, szokta mondani Kalácska elvtárs.\n
# P: {'49': '46'}
# V: {'49': '46'}
# Irrel: []
#
# True pos 50
# - Át_p50 vannak itatva_v50...\n
# P: {'50': '47'}
# V: {'50': '47'}
# Irrel: []
#
# True pos 51
# Az emberek meg imbolyogtak az új szelekben, látni lehetett, hogy igyekeznek egymás segítségére, hogy végig_p51 ne vágódjanak_v51 a hatalmas sártócsákban.\n
# P: {'51': '48'}
# V: {'51': '48'}
# Irrel: []
#
# False neg 53
# True pos 52
# De csak meg_p52 kell találnunk._v52\nVegye meg ezt, Ferdi bácsi - húzta ki Ildi a hóna alól, hogy odamutassa, Nadragulyevác Szávó üstökös életű költőnk örök érvényű tankölteményeinek öt egyforma kötetét, és elé nyújtotta, futószalagon (Aranyos Reske csak távolabbi szemlélője volt a jelenetnek, a be_p53 nem avatkozás_v53 elve alapján).\n
# P: {'52': '49'}
# V: {'52': '49'}
# Irrel: ['50', '50', '51', '51']
#
# False neg 54
# Nehezen képzelhető_v54 el_p54; de akkor is, mi volt a formája?\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 55
# Semmi olyat nem mondtam, amit az ön jelenlétében is meg_p55 ne ismételhetnék_v55.\n
# P: {'55': '52'}
# V: {'55': '52'}
# Irrel: []
#
# True pos 56
# Nem akarnak egyéni érzelmeimben befolyásolni, de itt nem érzelmekről, hanem elvekről és tényekről van szó, és ha igazán az eszmélő nép, a " népünk ", valamint " a költészet, a tiszta szellem " mellé akarok állni, el_p56 kell fogadnom_v56 a nagy Petényi ujjmutatását, aki Réti Palit már negyvennégy nyarán, londoni emigrációjában, könyörtelenül az árulók közé taszította.\n
# P: {'56': '53'}
# V: {'56': '53'}
# Irrel: []
#
# Lépek s kiáltok.
# P: {}
# V: {}
# Irrel: []
#
# True pos 57
# S zajongok, amig Egy röggel be_p57 nem tömik_v57 szájamat.\n
# P: {'57': '54'}
# V: {'57': '54'}
# Irrel: []
#
# False neg 58
# False neg 59
# Egyik-másik annyi tiszteletlenséget, izgatást, szemérmetlen (a való tényeknek egyáltalában meg_p58 nem felelő_v58) önleleplezést tartalmazott, hogy ezekért nem is vállalhattam a felelősséget egy olyan, eléggé el_p59 nem ítélhető_v59 jogrendszerben, amely ilyesmiért nem a korszellem és az örök szellem közös leányát, a Múzsát, hanem bűnös hanyagsággal a költőt vonja perbe.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 60
# False pos 61
# Egy portugál bölcselő szerint, ha egy rétegtől munkaerőt, terményt, mindent olcsón meg_p60 lehet kapni_v60, a vásárlók eszmevilága szükségszerűen úgy alakul, hogy el_p61 sem tudják képzelni_v61: rendkívülinek, sőt afféle szerződésszegésnek érzik, ha valami mégsem olcsó, vagy kiváltképp nem kapható.\n
# P: {'60': '55', '61': '56'}
# V: {'60': '55'}
# Irrel: ['56']
#
# False neg 62
# Ti fogjátok tudtául adni, hogy Kolozsvár felett zivatar vonul, s nedveteknek hirtelen újjáéledése jelenti meg a mélyen alvónak és fel_p62 nem ébredőnek_v62 az újdonatúj tavaszt.\n
# P: {}
# V: {}
# Irrel: ['57', '57']
#
# True pos 63
# De ez is elég volt ahhoz, hogy az öregember el-elszoruló szívvel induljon lefelé a meredek kerten át, s meg_p63 se álljon_v63 az íróasztaláig.\n
# P: {'63': '58'}
# V: {'63': '58'}
# Irrel: []
#
# False neg 64
# Mintha valakiket megleptem volna itt, kik test szerint bár láthatatlanok, azóta súlyosabban itt lakoznak, mióta szemmel fel_p64 nem foghatók_v64.\n
# P: {}
# V: {}
# Irrel: []
#
# Anya jópofa volt.
# P: {}
# V: {}
# Irrel: []
#
# True pos 65
# Meg_p65 kell hagyni_v65.\n
# P: {'65': '59'}
# V: {'65': '59'}
# Irrel: []
#
# True pos 66
# Egyszerre... rétegesen... az egymásutániság csapdája, ha le_p66 akarnám írni_v66... ha valamelyik firkász venné a bátorságot és összerendezné... kikerekítgetné szépen... a vázlatot... a részleteket... öntelten kukorékolná, mint a kakas a szemétdombon, " nézzétek, emberek, ez az én művem, ezt mind én csináltam, egyes-egyedül, tőlem kelt fel az Isten napja...
# P: {'66': '60'}
# V: {'66': '60'}
# Irrel: ['61', '61']
#
# True pos 67
# "\nAmit fel_p67 lehet ragasztani_v67.\n
# P: {'67': '62'}
# V: {'67': '62'}
# Irrel: []
#
# True pos 68
# És hogy meg_p68 tetszett tiltani_v68 neki, hogyha én otthon felejtem valamimet, ő kölcsönadja...\n
# P: {'68': '63'}
# V: {'68': '63'}
# Irrel: []
#
# Nem is volt botrány voltaképpen, mert a fürdőzők s úszómesterek egyaránt hazamentek, csak két három elkésett látogató csavarta ki vizes fürdőruháját, megállva a medence kőszegélyén.
# P: {}
# V: {}
# Irrel: ['64', '64']
#
# Mint később állították, nem hittek a saját szemüknek, megpillantva a szürkületben a meztelen alakokat.
# P: {}
# V: {}
# Irrel: []
#
# Azt képzelték, érzékcsalódás áldozatai lettek, avagy talán a délibáb Egerbe költözött a Hortobágyról.
# P: {}
# V: {}
# Irrel: []
#
# True pos 69
# Mikor pedig rá_p69 kellett jönniük_v69, hogy nem káprázik a szemük, lóhalálában elhagyták a fürdőt.\n
# P: {'69': '65'}
# V: {'69': '65'}
# Irrel: []
#
# False pos 70
# True pos 71
# Hol elöl, hol hátul ültek egyre többen, s a hó nőtt akkorára, hogy ha meg_p70 nem lett volna fagyva_v70, ki_p71 sem látszik_v71 belőle az ember.\n
# P: {'70': '66', '71': '67'}
# V: {'71': '67'}
# Irrel: ['66']
#
# True pos 72
# - Az Écel emberei be_p72 vannak építve_v72 a rendőrségre.\n
# P: {'72': '68'}
# V: {'72': '68'}
# Irrel: []
#
# True pos 73
# Most jön_v73 csak ki_p73 a szobából Mendezné, karján összehajtogatott takaró.\n
# P: {'73': '69'}
# V: {'73': '69'}
# Irrel: []
#
# True pos 74
# F. sokáig távol tartotta magát a sajtótól, mígnem néhány évvel ezelőtt egy népszerű napilap publicisztikai rovatvezetője - egykori kollégánk - felajánlotta neki a helyettesi státust, amit F. némi habozás után el_p74 is fogadott_v74.\n
# P: {'74': '70'}
# V: {'74': '70'}
# Irrel: []
#
# True pos 75
# Azt is megbeszélték, hogy ő vásárol_v75 majd be_p75 szombaton.\n
# P: {'75': '71'}
# V: {'75': '71'}
# Irrel: []
#
# False neg 76
# Aztán el_p76 kellett még mondanom_v76 az öregasszonynak: - Együtt voltunk - magyarázkodnom: - Zeitzban -, s valahogyan szigorú, már-már számon kérő kérdésére: - És miért nem együtt jöttek haza? - mentegetőznöm szinte: - Elváltunk.\n
# P: {}
# V: {}
# Irrel: ['72', '72']
#
# False neg 77
# A ki_p77 nem mondható_v77, de a társadalomban még élő igazság és jogérzet, a cselekvésre sarkalló akarat, az éber lelkiismeret jelenik meg velük a színen.\n
# P: {}
# V: {}
# Irrel: ['73', '73']
#
# Ide esett.
# P: {}
# V: {}
# Irrel: []
#
# Többet nem fogja megmoccantani senki.
# P: {}
# V: {}
# Irrel: []
#
# False neg 78
# Pedig a többiek már trappolnak is az emeletről, hogy újra utánam_p78 dobják_v78, mert dühük már fáj: csak annyit éreznek, hogy mekkora feszültség van egy mozdulatlanul álló szörnyű nagy kőtömbben.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 79
# Mint egyike azoknak, akik mindig az egészben gondolkoztak, nem hittek abban, hogy valamilyen szempontok szerint le_p79 kellene írni_v79 holmi tételeket, amelyeket persze máshol se vennének úgysem könyvelésbe az ötbe-hatba-hétbe hasított egynyelvű kultúránkból.\n
# P: {'79': '74'}
# V: {'79': '74'}
# Irrel: []
#
# True pos 80
# Most a kora őszi csepergésben, a fénylő síneken ágyúval, horkoló katonákkal úgy kattogtak át itt is a vonatok, mint a legparányibb bakterház előtt; még nappal sem volt, hogy félrehúzott ajtókban láblógatva ücsörgő szürke alakok, bár kibetűzzék s egy pillanat múlva el_p80 is felejtsék_v80, hogy van ilyen állomás...\n
# P: {'80': '76'}
# V: {'80': '76'}
# Irrel: ['75', '75']
#
# True pos 81
# Csóka talált a patakban egy vaskalapot, két helyen át_p81 volt lyuggatva_v81, és tele volt iszappal.\n
# P: {'81': '77'}
# V: {'81': '77'}
# Irrel: []
#
# True pos 82
# -... ha meg kellett érteni: mi történik hirtelen bennem, fel_p82 kellett fogni_v82, mit érzek, nagyon magamra voltam utalva.\n
# P: {'82': '79'}
# V: {'82': '79'}
# Irrel: ['78', '78']
#
# True pos 83
# Figyeljünk_v83 most oda_p83 egy, látszólag, formai vonásra.\n
# P: {'83': '80'}
# V: {'83': '80'}
# Irrel: []
#
# True pos 84
# - Na, ülj hamar a hátamra, estig vissza_p84 kell érnem_v84, mert este szolgálatba megyek.\n
# P: {'84': '81'}
# V: {'84': '81'}
# Irrel: []
#
# True pos 85
# Ha valamit el_p85 kell intézni_v85 valahol, én maga helyett mindent elintézek.\n
# P: {'85': '82'}
# V: {'85': '82'}
# Irrel: []
#
# False neg 86
# False neg 87
# Vajon nem törülné_v86 -e el_p86 azt a magabiztos mozdulatát, mellyel a XX. századi Csák visszamutat_v87 ma a dunántúli város középkori történetére, vissza_p87 a ködszerű múltra.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 88
# Szinte bárhol fel_p88 lehet ütni_v88 a Válogatott versek kötetét, s bő ízelítő kínálkozik a tízes évek végéről a sebesen változó, bizarr, elrugaszkodott, nehezen vagy alig érthető képzetekből.\n
# P: {'88': '83'}
# V: {'88': '83'}
# Irrel: []
#
# False neg 89
# Szeretsz?? kérdeztem a lánytól s vártam, hogy mondjon valamit, amitől ketté_p89 hasadnak_v89 a falak.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 90
# Indulás_v90 haza_p90!\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 91
# -... ha mégis el_p91 tudja felejteni_v91...\n
# P: {'91': '84'}
# V: {'91': '84'}
# Irrel: []
#
# Az ember csavarog.
# P: {}
# V: {}
# Irrel: []
#
# False pos 92
# El_p92 se tudja képzelni_v92, hogy mást is lehet.\n
# P: {'92': '85'}
# V: {}
# Irrel: ['85']
#
# True pos 93
# - Meg_p93 lehet dögölni_v93 mellette!\n
# P: {'93': '86'}
# V: {'93': '86'}
# Irrel: []
#
# True pos 94
# Az október 26-i ülésükön elhatározva, hogy minden nap össze_p94 fognak ülni_v94, nem kevesebb, mint 22 pontban rögzítették a tennivalókat.\n
# P: {'94': '87'}
# V: {'94': '87'}
# Irrel: []
#
# True pos 95
# Aki veled le_p95 tudott feküdni_v95...\n
# P: {'95': '88'}
# V: {'95': '88'}
# Irrel: []
#
# True pos 96
# Nagy Imre, aki Magad 17 évig voltál emigráns, aki hazatérve ezeket mondottad: " Az volt a bűnöm, hogy szerveztem a földműves nép harcát a feudális nagybirtokrendszer megszüntetéséért, azért, hogy azé legyen a föld, aki megműveli; de ha el_p96 is űztek_v96 innen messze idegenbe, nem voltam földönfutó, lélekben, gondolatban mindig itt voltam köztetek ": ma eljöttek sírodhoz a világ négy sarkából a magyar emigránsoknak ezrei, akik - akárcsak Te - lélekben sohasem szakadtak el a hazától.\n
# P: {'96': '89'}
# V: {'96': '89'}
# Irrel: ['90', '90']
#
# True pos 97
# True pos 98
# És különösképpen utálja azokat, akik ki_p97 merték nyitni_v97 a szájukat, fel_p98 merték emelni_v98 a hangjukat, amikor ő lapult.\n
# P: {'97': '91', '98': '92'}
# V: {'97': '91', '98': '92'}
# Irrel: []
#
# False neg 99
# Kuczka és a vele azonos véleményen lévők határozottan állították, hogy az egyetlen lehetséges, kommunista íróhoz méltó magatartás, amely ezentúl a pártot is segíti, az, hogy nyíltan és tisztán megírják tapasztalataikat, feltárják a hibákat, nem várva_v99 most már meg_p99, amíg megint ellentmond költészetüknek a valóság, nem is szólva arról, amíg megint fejükre koppint a párt is, hogy a nehéz időkben lehunyt szemmel járták a világot.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 100
# Ezt a kiváló tudóst az írás és a publikálás lehetőségeitől tíz éven át fosztotta meg a rendszer, mert bírálni merte - nem sokkal a háború befejezte után, a koalíciós időszak kezdetein - a kommunista párt taktikáját és stratégiáját, felhívta a figyelmet a diktatúra készülő veszélyeire és nem utolsósorban szembe_p100 mert szállni_v100 - Révai Józseffel a kommunista párt és a demokrácia viszonyát illetően.\n
# P: {'100': '94'}
# V: {'100': '94'}
# Irrel: ['93', '93']
#
# True pos 101
# Ha mocskosan törpe a történelem - meg_p101 kell építenünk_v101 a magunk történelmét.\n
# P: {'101': '95'}
# V: {'101': '95'}
# Irrel: []
#
# False neg 102
# Teljes objektivitása ugyanis önmagában van, a maga tisztaságában nem bányászható_v102 ki_p102.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 103
# Szóval, most mindent oda_p103 tudnál dobni_v103, vőlegényt, biztonságot, mindent - és én semmit sem ígértem, semmit se kínáltam ezért.\n
# P: {'103': '96'}
# V: {'103': '96'}
# Irrel: []
#
# True pos 104
# De nem tudta megállni, hogy még egyszer el_p104 ne búcsúzzon_v104 Marianntól; most ugyan elég sután, szemlesütve csinálta.\n
# P: {'104': '97'}
# V: {'104': '97'}
# Irrel: []
#
# True pos 105
# A belső udvart a szomszéd üres telek felől is meg_p105 lehet közelíteni_v105, egy szögesdróttal biztosított vasajtón.\n
# P: {'105': '98'}
# V: {'105': '98'}
# Irrel: []
#
# True pos 106
# Most először érzek olyasmit, hogy egy sejtelem hatására az embernek le_p106 tud esni_v106 hirtelen a hőmérséklete.\n
# P: {'106': '99'}
# V: {'106': '99'}
# Irrel: []
#
# True pos 107
# Inkább majd a végén részletezi az eredményt - bár meg_p107 volt győződve_v107 róla, hogy nem éri meglepetés.\n
# P: {'107': '100'}
# V: {'107': '100'}
# Irrel: []
#
# True pos 108
# - Itt akarsz megfagyasztani bennünket? - vakkant fel valamelyikünk, és be_p108 akart nyitni_v108 egy ajtón, hogy melegebb helyiség után kutasson.\n
# P: {'108': '102'}
# V: {'108': '102'}
# Irrel: ['101', '101']
#
# True pos 109
# Éreztem, hogy meg_p109 kell kapaszkodnom_v109 valamiben.\n
# P: {'109': '103'}
# V: {'109': '103'}
# Irrel: []
#
# True pos 110
# - Semmibe, csak be_p110 kellene táplálni_v110.\n
# P: {'110': '104'}
# V: {'110': '104'}
# Irrel: []
#
# True pos 111
# - Eleinte még kijárnak a tanyára disznót nevelni, reggel-este etetik őket, de rá_p111 kell jönniük_v111, hogy egy disznón nem marad több hasznuk ötszáz-ezer forintnál, mert a drága kukoricát már nekik is a boltban kell megvásárolniuk.\n
# P: {'111': '105'}
# V: {'111': '105'}
# Irrel: []
#
# True pos 112
# Tudtam róla, hogy megszállott rendőr, ezért is kapta becézésképpen a nagy francia rendőrzseni nevét, néha éjjel kettőkor hívta fel a kollégáit, hogy mostanáig járt egy körözött betörő nyomában, rábukkant, itt áll a lakása előtt, most le_p112 lehetne tartóztatni_v112, jöjjenek el segíteni neki.\n
# P: {'112': '107'}
# V: {'112': '107'}
# Irrel: ['106', '106', '108', '108']
#
# False neg 113
# - Ezt a kísérletet néhány megjelölt úszó fadarabbal is épp ilyen jól el_p113 lehetett volna végezni_v113 - mondja F., a sokat tapasztalt öreg környezetvédő szakember.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 114
# Mivel tudtam, hogy előbb-utóbb mindenképpen behívnak katonának, meg_p114 akartam előzni_v114, önként jelentkeztem a Légierőhöz.\n
# P: {'114': '109'}
# V: {'114': '109'}
# Irrel: []
#
# True pos 115
# Arcán elszánt kifejezéssel állt oda a meszelt rajtvonalra, tudtuk, meg_p115 fog tenni_v115 mindent, ami tőle telik.\n
# P: {'115': '111'}
# V: {'115': '111'}
# Irrel: ['110', '110']
#
# True pos 116
# - És te el_p116 akarsz úszni_v116 Verdalóba? - kérdeztem hitetlenül.\n
# P: {'116': '112'}
# V: {'116': '112'}
# Irrel: []
#
# Feltűnően öltözködő, mozgékony kis barátnője mellett úgy tűnt, mint egy nehézkes tengeri hal, vezetője, a fürge pilótahal mellett, és valószínűleg ez is határozta meg kapcsolatuk jellegét.
# P: {}
# V: {}
# Irrel: ['113', '113']
#
# True pos 117
# True pos 118
# El_p117 akart fordulni_v117, de a lány hirtelen újra ráemelte a szemét, János visszanézett, és a kitágult szemekből megértette, hogy a lány lát rajta valami sebet vagy rendetlenséget, amelyre fel_p118 akarja hívni_v118 a figyelmét.\n
# P: {'117': '114', '118': '115'}
# V: {'117': '114', '118': '115'}
# Irrel: []
#
# True pos 119
# A szakítás mellett szólt az is, hogy Altschuler vagy Nagyezsda is tudomást szerezhet a találkozásokról, és János egyelőre el_p119 akarta kerülni_v119 a botrányt.\n
# P: {'119': '116'}
# V: {'119': '116'}
# Irrel: []
#
# True pos 120
# " A büntetés elején nagyobb fokú nélkülözéssel kell felkelteni a tudatot az elítéltben, hogy a jogsértés súlyos következményekkel jár, és akaratát alá_p120 kell rendelnie_v120 egy felsőbb akaratnak.
# P: {'120': '117'}
# V: {'120': '117'}
# Irrel: []
#
# True pos 121
# "\nEgészen el_p121 is feledtem_v121 a kedves édesapát.\n
# P: {'121': '118'}
# V: {'121': '118'}
# Irrel: []
#
# True pos 122
# Olyan embert, aki érvényt szerez a törvény szavának; s aki azon nyomban le_p122 is köszönt_v122 a tisztéről, mihelyst megszűnt a szükségállapot vagy megoldódott a viszály.\n
# P: {'122': '119'}
# V: {'122': '119'}
# Irrel: []
#
# True pos 123
# Ott az ajtó, a hallba nyílik, ki_p123 kell nyitni_v123.\n
# P: {'123': '120'}
# V: {'123': '120'}
# Irrel: []
#
# True pos 124
# De hiszen ez meg_p124 van repedve_v124, folyik a petróleum.\n
# P: {'124': '121'}
# V: {'124': '121'}
# Irrel: []
#
# True pos 125
# Nem akarom, hogy azt higgye, valami tolvaj szomszédságába került - tette_v125 még hozzá_p125 az ujját fölemelve.\n
# P: {'125': '122'}
# V: {'125': '122'}
# Irrel: []
#
# True pos 126
# Tizenkét évig rá_p126 sem néztem_v126 más nőnemű lényre.\n
# P: {'126': '123'}
# V: {'126': '123'}
# Irrel: []
#
# False neg 127
# De ezen a csúcson - s ezt már a regény bizonyítja - elkezdtem gyanakodni erre az épségre, a normára: nem csapott_v127 -e be_p127, nem zárta -e fölpattinthatatlan tokba azt, ami több, nemesebb volt bennem: " az abnormalitásom ".\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 128
# True pos 129
# - Azért el_p128 ne rídd_v128 magad, szólt az apa, aki nem állhatta meg, hogy el_p129 ne kacagja_v129 magát, oly komikus volt az előrecsuklott térdű, reszkető figura.\n
# P: {'128': '124', '129': '126'}
# V: {'128': '124', '129': '126'}
# Irrel: ['125', '125']
#
# True pos 130
# Ott élek mellette, s nem tudom elhinni - holott nagyon is el_p130 tudta hinni_v130, meg volt győződve, csak nagy néha nyilallt bele az esztelen gyanú, hogy tán mégsem igaz - mint éjjeli felriadáskor, hogy halottunk nem halt meg.\n
# P: {'130': '127'}
# V: {'130': '127'}
# Irrel: ['128', '128', '129', '129', '130', '130']
#
# True pos 131
# True pos 132
# Nem jutott eszembe, hogy a mennyei dicsőség révült állapotát sajnálatos módon meg_p131 kell előznie_v131 annak, hogy meg_p132 kell halnunk_v132 hozzá.\n
# P: {'131': '131', '132': '132'}
# V: {'131': '131', '132': '132'}
# Irrel: []
#
# True pos 133
# Ebben a sűrű füstben el_p133 se látunk_v133 odáig.\n
# P: {'133': '133'}
# V: {'133': '133'}
# Irrel: []
#
# True pos 134
# Akárhogy is van, hősöm ő nekem, hajtogattam, hogy legalább fikcióvá hazudjam ezt a szörnyűséget, de meg_p134 nem nyugodtam_v134.\n
# P: {'134': '134'}
# V: {'134': '134'}
# Irrel: []
#
# True pos 135
# Egyszerű vágásokkal, nagyításokkal, egybefényképezésekkel: az Ezeregyéjszaka minden csodáját fel_p135 tudja eleveníteni_v135 a néző szeme előtt: tengeri ütközetet egy lavór vízben, a vízözön, a Mars-utazás, Karthágó pusztulásának képét - makettből.\n
# P: {'135': '135'}
# V: {'135': '135'}
# Irrel: []
#
# False neg 136
# A gyógynövény párlat egyik alkotó elemét ma is csak én tudom, a porcelán régi fénye az ismert hőfokon is csak egy bizonyos összetételű mázzal érhető_v136 el_p136: ennek a titkát sem fedtem föl.\n
# P: {}
# V: {}
# Irrel: ['136', '136']
#
# - Semmit!
# P: {}
# V: {}
# Irrel: []
#
# True neg
# Szét_p0 vannak azok már a világban, egyik itt, a másik ott, nem törődnek véle.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 137
# Ettől sem tanultam meg " főzni ", de megtanultam elkészíteni néhány ételt, főként különböző salátákat, s egy-két komolyabb fogást is, amiből olykor, nagyritkán össze_p137 tud állni_v137 egy-egy vacsora, és amelynek elkészítése ilyenkor, a kudarctól való drukk vagy sokk állandó jelenléte dacára is, inkább kedvemre mint ellenemre van.\n
# P: {'137': '138'}
# V: {'137': '138'}
# Irrel: ['137', '137']
#
# False neg 139
# True pos 138
# Nehezen tudom elképzelni, hogy apám a valamelyik haszonleső maffiózó által elétárt Porhüvelyt ne vizsgálta_v138 volna meg_p138 alaposan, valóban azt kapja_v139 -e meg_p139, amit áhít.\n
# P: {'138': '139'}
# V: {'138': '139'}
# Irrel: []
#
# True pos 140
# Ram lelkében mozdult_v140 csak meg_p140 valami, mert ő érteni vélte a Mesternek ideáját.\n
# P: {'140': '140'}
# V: {'140': '140'}
# Irrel: []
#
# True pos 141
# Leszúrlak, ha meg_p141 akarsz lógni_v141.\n
# P: {'141': '141'}
# V: {'141': '141'}
# Irrel: []
#
# True pos 142
# - Ez egy kétségbeesett segélykiáltás volt, s névvel jegyezve az első eredménye az lett volna, hogy két óra múltán már le_p142 is tartóztattak_v142 volna.\n
# P: {'142': '142'}
# V: {'142': '142'}
# Irrel: []
#
# True pos 143
# Addig is azonban meg kellene komolyan vizsgálni, hogy azok az állami kiadók, amelyeknek elvileg magyar nyelvű könyveket is ki_p143 kellene hozniok_v143, ezt a feladatukat miért nem teljesítik.\n
# P: {'143': '143'}
# V: {'143': '143'}
# Irrel: []
#
# False neg 144
# True neg
# Az ilyesmihez pedig hozzá_p144 voltam szokva._v144\nVásárlók mind el_p0.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 145
# Panaszolta is később az igazgató Prielle Kornéliának: " különös asszony ez a Jászai: nekiadtam az Évát, s még csak fel_p145 se csillant_v145 a szeme!
# P: {'145': '144'}
# V: {'145': '144'}
# Irrel: []
#
# False neg 146
# "\nHogy menekűlt az a réműlt kukac, mikor szétbuggyantottad rejtekét! hogy bújt, vissza, az eltűnt éjbe! még beljebb, a mag alá! hogy bújt_v146 csupasz titka be_p146 a takaró húsba, az áldott édenbe, a biztosba!...
# P: {}
# V: {}
# Irrel: []
#
# Szép vonaglása tán hóhéra kezét átkozta, s azt jósolta: " Nem maradsz rejtve te sem a romlástól! nem a leleplezéstől: életed ura a vak véletlen!
# P: {}
# V: {}
# Irrel: []
#
# "...
# P: {}
# V: {}
# Irrel: []
#
# Sorstragédia szinháza lett az a kék szilvaszem...\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 147
# Amata megemberelhette magát, gondolta Latinus, általában nem esznek főttet ők este, de reggel nagyon kókadozott, le_p147 kellett vágni_v147 egy bárányt, prédába nem hagy az ember semmit akkor sem, ha világbirodalom ura lesz.\n
# P: {'147': '145'}
# V: {'147': '145'}
# Irrel: []
#
# True pos 148
# True pos 149
# True pos 150
# Az őrrel fertelmesen ordítottak egymásra, míg Annuska ki_p148 nem rohant_v148, félre_p149 nem tolta_v149 az őrt, és be_p150 nem rántotta_v150 Anzsut meg a képeket a kapun.\n
# P: {'148': '146', '149': '147', '150': '148'}
# V: {'148': '146', '149': '147', '150': '148'}
# Irrel: []
#
# True pos 151
# Elmondtam már, milyenek voltunk, s ebből megérthetitek, hogy Bálint és az őrnagy miért csak nekem mondta meg, hol van Henriett, és miért hitte el nálunk mindenki, amit Bálinték el_p151 akartak hitetni_v151, hogy Henriett utánament a szüleinek, és velük együtt elhagyta a várost.\n
# P: {'151': '151'}
# V: {'151': '151'}
# Irrel: ['149', '149', '150', '150']
#
# True pos 152
# Megint azt a kétségbeesést érezte, amit már annyiszor át_p152 kellett élnie_v152, mennyire nem számíthat senkire önmagán kívül, s hogy egy négytagú családban milyen egymagára utaltan él, voltaképpen milyen árván.\n
# P: {'152': '152'}
# V: {'152': '152'}
# Irrel: []
#
# True pos 153
# Hát oda dolgozhatnék a mama, akár a szövetkezetben magában, ott olyan viszonylag maga korabeliek vannak, hetven körüliek, de ha az fárasztaná, ki_p153 is adják_v153 neki a munkát, pepecselhet vele otthon.\n
# P: {'153': '153'}
# V: {'153': '153'}
# Irrel: []
#
# True pos 154
# Késő délután egyszer csak megjelenik József, Jablonczay Lenke alig vet rá pillantást, Szabó Elek annál figyelmesebben nézi, mint aki fel_p154 akarja mérni_v154, milyen emlékkel kell majd megküzdenie.\n
# P: {'154': '154'}
# V: {'154': '154'}
# Irrel: []
#
# True pos 155
# Komolyan beszélgetni, elmagyarázni, kiben mikor érett meg a felismerés, hogy házasságot kellene kötniök, persze nem volt alkalom, de mire bevégezték az étkezést, valahogy mindketten természetesnek találták már, hogy Amalfi velük maradjon, míg délutáni szolgálata meg_p155 nem kezdődik_v155.\n
# P: {'155': '156'}
# V: {'155': '156'}
# Irrel: ['155', '155']
#
# True pos 156
# Addig körmöl, míg az újbóli és újbóli konyak adagok rá_p156 nem hozzák_v156 az álmosságot.\n
# P: {'156': '157'}
# V: {'156': '157'}
# Irrel: []
#
# True pos 157
# Már indul_v157 is vissza_p157.\n
# P: {'157': '158'}
# V: {'157': '158'}
# Irrel: []
#
# True pos 158
# Érdekes, hogy ezzel a levelezéssel együtt olvasva Berzsenyi költeményeit, azok egymást elragadóan gazdagítják és ki_p158 is egészítik_v158.\n
# P: {'158': '159'}
# V: {'158': '159'}
# Irrel: []
#
# True pos 159
# Nyakát hátraszegte, derekát kifeszítette, mert ott érezte szívében azt az erőt, amely azt súgta neki, hogy nincs a hadnagynak olyan feltétele, amelyet most el_p159 ne fogadna_v159 boldogan.\n
# P: {'159': '160'}
# V: {'159': '160'}
# Irrel: []
#
# True pos 160
# True pos 161
# De más tekintetben is pazarló módon viselte magát, szólván is dagadozva, mintha meg_p160 akarná venni_v160 az egész Hargitát:\nHazámban, a Székelyföldön fel_p161 vannak háborodva_v161.\n
# P: {'160': '161', '161': '162'}
# V: {'160': '161', '161': '162'}
# Irrel: []
#
# False neg 162
# True pos 162
# S így búslakodván érzetem csapkodásaiban, kedves anyám jutott eszembe, s el_p162 is gondoltam_v162, hogy bezzeg az ő kies kertjében más gyümölcs termik; s el_p162 azt is, hogy az a gyümölcs most jobb volna nekem, mert anyám nem azt akarná, hogy én álljak helyt a bajban, hanem azt inkább, hogy az öröm állja meg mellettem a helyét.\n
# P: {'162': '163'}
# V: {'162': '163'}
# Irrel: ['164', '164']
#
# True pos 164
# De ahogy oldozta volna a cipőt, Mihályka elhúzta álmában a lábát; majd azután is elhúzta folyton, valahányszor az anyja le_p164 akarta venni_v164 róla a cipőt.\n
# P: {'164': '165'}
# V: {'164': '165'}
# Irrel: []
#
# True pos 165
# Adjál csak ide pénzt: ne félj, mindjárt meg_p165 fogja mondani_v165 a véleményét a kántor úr.\n
# P: {'165': '166'}
# V: {'165': '166'}
# Irrel: []
#
# True pos 166
# ( Ez be_p166 volt karikázva._v166)\n
# P: {'166': '167'}
# V: {'166': '167'}
# Irrel: []
#
# True pos 167
# Másolt: " Ma még én menjek át...! sóhajtotta Lipton, és akkor a döntőben ki_p167 is kaphatok_v167, 42-42 ponttal állunk, A.A.A.A. és én, és nem baj a második hely.\n
# P: {'167': '169'}
# V: {'167': '169'}
# Irrel: ['168', '168']
#
# True pos 168
# True pos 169
# Ha meg_p168 vagy fázva_v168, nem annyi már, ha rá_p169 is fázol_v169.\n
# P: {'168': '170', '169': '171'}
# V: {'168': '170', '169': '171'}
# Irrel: []
#
# False neg 170
# De Jucika riadtan kapja_v170 a kezét el_p170.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 171
# Már ki_p171 is derült_v171 újra a képünk Rózsikával.\n
# P: {'171': '172'}
# V: {'171': '172'}
# Irrel: []
#
# True neg
# - Meg_p0, drágám!
# P: {}
# V: {}
# Irrel: []
#
# True neg
# True pos 172
# True pos 173
# Meg_p0!\nmég egyszer sem sírta el magát én hiába zokogok a lyukas zoknikba a lyukakkal teli ólomteknőbe ki_p172 kell várnom_v172 gabit ahogy egyszer csak némán felsír zokog egész nap a rádióban én meg csapkodni kezdem a hasam úgy röhögök igen én is benne a rádióban úgy röhögök a boldogságtól hogy a gabi végre ismét: sír. nem csak tisztábban okosabban tagol kevesebbet affektál s főleg nem patetizál hanem ismét: sír. milyen szép lesz mennyire igazi reggel felcsapom a kossuthot és hallom benne ahogyan gabi: sír. és aztán teszem szépen a dolgomat megyek ide-oda ólálkodok itt-ott néha talán fel_p173 is jegyzek_v173 valamit de közben tudom ha hazaérek s ismét felcsapom a kossuthot hallani fogom benne ahogyan gabi: sír. és hát ez persze többek között: olyan kosztolányis is. a nagysikerű előadás másnapján a következő sorokat olvashattuk a magyar szó-ban:\nÁllva alvók.
# P: {'172': '174', '173': '175'}
# V: {'172': '174', '173': '175'}
# Irrel: ['173', '173']
#
# True pos 174
# Fel_p174 vannak függesztve_v174, mint a lampionok.\n
# P: {'174': '176'}
# V: {'174': '176'}
# Irrel: []
#
# True pos 175
# True pos 176
# Tulajdonképpen, ők ily önzetlenül ajándékozgatják egymást mindaddig, mígcsak fel_p175 nem cseperednek_v175 és képzeletük el_p176 nem romlik_v176.\n
# P: {'175': '177', '176': '178'}
# V: {'175': '177', '176': '178'}
# Irrel: []
#
# False neg 177
# [2] Az idegen állampolgárok és a hontalanok csakis valamely nemzetközi megállapodás alapján vagy a kölcsönösség feltételei között adhatók_v177 ki_p177.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 178
# True pos 179
# [4] A kormány által elfogadott határozatokat és rendeleteket alá_p178 kell írnia_v178 a miniszterelnöknek és ellenjegyezniük kell az alkalmazásba tételükre kötelezett minisztereknek, és azokat közzé_p179 kell tenni_v179 Románia Hivatalos Közlönyében.\n
# P: {'178': '179', '179': '180'}
# V: {'178': '179', '179': '180'}
# Irrel: []
#
# True pos 180
# True pos 181
# Figyelemmel arra, hogy ilyen esetek a gyakorlatban számos alkalommal és élethelyzetben fordulnak, illetve fordulhatnak elő, az az álláspontunk, hogy a jogalkotónak egyértelműen meg_p180 kell határoznia_v180 a konfliktusok esetén követendő eljárás - " egyeztetés " - szabályait, és ki_p181 kell mondania_v181 azt, hogy az egyetértési, illetőleg véleményezési jog figyelmen kívül hagyásával hozott döntésekhez milyen jogkövetkezmény fűződik.\n
# P: {'180': '182', '181': '183'}
# V: {'180': '182', '181': '183'}
# Irrel: ['181', '181']
#
# False neg 182
# Sokszor mereven értelmezték, adott esetben a gyermek ellen fordították azokban azt a gyermekvédelmi törvényben deklarált elvet is, amely szerint " szociális okból gyermek nem emelhető_v182 ki_p182 a családból ".\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 183
# Békéscsabát fel_p183 kell zárkóztatnunk_v183 először Magyarországhoz, hogy 2002-ben ott lehessünk az unió szintjén - még ha az egyik legalsó szinten is.\n
# P: {'183': '184'}
# V: {'183': '184'}
# Irrel: []
#
# True pos 184
# Én azt mondtam el kompromisszumként, hogy jogtechnikailag az pontosan olyan megoldás lesz számomra, hogy valamennyi esetben - erre mondtam azt, hogy más papírt kell írnunk sok száz beszerzésnél - meg_p184 lesz említve_v184 a (3) bekezdésben eredetileg szereplő tárgyköre a bizottsági véleményalkotásnak.\n
# P: {'184': '186'}
# V: {'184': '186'}
# Irrel: ['185', '185']
#
# Úgy tudom, hogy a személyi ügyeket általában zárt ülésen szokták tárgyalni, kivéve akkor, ha az érintett felek beleegyeznek a nyílt ülésbe.
# P: {}
# V: {}
# Irrel: []
#
# True pos 185
# Meg_p185 kell mondanom_v185, most nem látom, hogy van -e ilyen nyilatkozat.\n
# P: {'185': '187'}
# V: {'185': '187'}
# Irrel: []
#
# True pos 186
# Ezeket az áremeléseket a kórházaknak ki_p186 kellett fizetni_v186, ugyanakkor a visszapótlás csak 20 százalék értékben történt meg.\n
# P: {'186': '188'}
# V: {'186': '188'}
# Irrel: ['189', '189']
#
# True pos 187
# A kihívásokról nem szeretnék beszélni, a listák a képernyőn is megjelentek, verbálisan a szövegben is olvashatóak voltak, hármat azonban - úgy érzem - külön is meg_p187 kell említenünk_v187, mert ezek nagyon jelentősen meghatározzák az Általános Rendezési Tervet.\n
# P: {'187': '190'}
# V: {'187': '190'}
# Irrel: []
#
# True pos 188
# Lehetőleg el_p188 kellene kerülni_v188, hogy olyan jogértelmezési kérdésekbe bonyolódjunk, mint hogy a közgyűlési határozatot a Tulajdonosi Bizottság betartotta -e vagy sem, hisz éppen ezért javasolta a bizottság a 2. határozati javaslatot, hogy most konkrétan próbáljunk meg előrejutni ebben a kérdésben.\n
# P: {'188': '191'}
# V: {'188': '191'}
# Irrel: ['192', '192']
#
# False neg 189
# Azt, hogy mi módon teszi_v189 ezt meg_p189 a koalíció vagy mi módon nem, azzal van, amikor egyetértünk, és van, amikor nem.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 190
# Kettő: ha arra gondolna, amire elvileg gondolhatna egy teljesen más tényállás esetén, a ki_p190 nem küldött_v190 anyag napirendre vételéről, az most nem áll fenn.\n
# P: {}
# V: {}
# Irrel: ['193', '193']
#
# True pos 191
# Azt is el_p191 kell mondanom_v191, számomra öröm az, hogy - bár kormánypárt és ellenzék, nyilván fővárosi szinten is, számos alkalommal összecsap - amikor arról van szó, hogy a főváros közbiztonsági helyzetét, a főkapitány úr beszámolóját tárgyaljuk, akkor ebben a kérdésben a felelősségünkre alapozva végül is egy irányba tudunk menetelni.\n
# P: {'191': '194'}
# V: {'191': '194'}
# Irrel: []
#
# True pos 192
# De ha valóban lenne ilyen, ennyire speciálisan ezekre a feladatokra szakosodott iskola, ezek a gyerekek, akik súlyos hátrányokkal küszködnek, nagyon nehezen viselnék el, ha át_p192 kellene menniük_v192 új közösségbe, új iskolába.\n
# P: {'192': '196'}
# V: {'192': '196'}
# Irrel: ['195', '195']
#
# True pos 193
# Az első módosító javaslat Marsi Péter Páltól származik, amely csak írásban került elénk, úgyhogy fel_p193 kell olvasnom_v193.\n
# P: {'193': '197'}
# V: {'193': '197'}
# Irrel: []
#
# False neg 194
# Egyet nagyon határozottan el_p194 kell, hogy hárítsak_v194: akkor mi nem tartoztunk a kormányzó pártok közé.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 195
# Mivel ezt a módosító-javaslat-csomagot most kaptam meg, természetesen fel_p195 fogom olvasni_v195, ahogy ez ilyenkor szokott lenni.\n
# P: {'195': '199'}
# V: {'195': '199'}
# Irrel: ['198', '198']
#
# True pos 196
# Tehát ezen a területen a felszíni tömegközlekedés korszerűsítését, az e hhez szükséges felszínrendbetételt, mindent meg_p196 kellene csinálni_v196.\n
# P: {'196': '200'}
# V: {'196': '200'}
# Irrel: []
#
# True pos 197
# Tehát egy olyan felvetést tett az illető, amit valószínűleg vissza_p197 fog vonni_v197, mert csacsiság volt, nem tekintette át a jogszabál yokat.\n
# P: {'197': '201'}
# V: {'197': '201'}
# Irrel: ['202', '202']
#
# True pos 198
# Az alkalmasság elbírálásába a jelenlegi használatba vevőt be_p198 kell vonni_v198.
# P: {'198': '203'}
# V: {'198': '203'}
# Irrel: []
#
# True pos 199
# False pos 200
# "\nEl_p199 tud készülni_v199, egy ekkora létesítménynek egy hónap alatt el_p200 kell tudni készülni_v200.\n
# P: {'199': '204', '200': '205'}
# V: {'199': '204'}
# Irrel: ['205']
#
# False neg 201
# (Marsi Péter Pál: Miért, le_p201 van zárva_v201 a vita?)\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 202
# Megvártam, amíg egy kicsit csend lesz, mert a saját szavamat nem értem, ami nem olyan nagy baj, de a kérdésnek mégiscsak el_p202 kell hangozni_v202.\n
# P: {'202': '206'}
# V: {'202': '206'}
# Irrel: []
#
# False neg 203
# Ha azt mondom, hogy 2-300 milliárd beruházásigényről van szó, és ehhez képest 3 milliárd kerül_v203 ide be_p203, akkor azt kell mondjam, hogy az aránytalan, ez így hiba.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 204
# True neg
# True neg
# True pos 205
# Az elnyert támogatás kizárólag a tárgyévben meghirdetett tervpályázatok céljára használható_v204 fel._p204\n* Vissza_p0 a tartalomjegyzékhez\nÚ vissza_p0 a címlaphoz\n(1) Minden sírhelytábla számát jelzőoszlopon, a sírhelysorok és sírhelyek számát pedig a sorokon túl jól látható helyen fel_p205 kell tüntetni_v205.\n
# P: {'205': '207'}
# V: {'205': '207'}
# Irrel: []
#
# False neg 206
# True pos 207
# Az erőmű építés vonatkozásában megvizsgálandó annak lehetősége is, hogy a beruházás több lépcsőben, 3 év alatt hogyan valósítható_v206 meg_p206:\nA felsorolt megoldásoknak meg_p207 kell felelni_v207 a mindenkor érvényes forgalmi rend kialakítására vonatkozó jogszabálynak.\n
# P: {'207': '208'}
# V: {'207': '208'}
# Irrel: []
#
# True pos 208
# Ha tulajdonos túlszámlázást megállapító kifogása helytálló, a többletösszeget és időarányos kamatait tulajdonos részére vissza_p208 kell fizetni_v208, vagy kérésére azt az esedékes díjfizetési kötelezettségébe kell betudni.\n
# P: {'208': '209'}
# V: {'208': '209'}
# Irrel: []
#
# False neg 209
# (11) A vonaljegyek vissza_p209 nem válthatók_v209.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 210
# True pos 211
# Ezek mind-mind eltérő szabályokkal bonyolódnak, s ember legyen a talpán, akár felszámoló, akár bíró az illető, aki ezt folyamatában szakszerűen végig_p210 tudja követni._v210\nVajon indokolt -e, hogy a Szocialista Párt frakcióvezetője magyarázkodik, hogy egy kormányzati szándék komoly és azt tényleg be_p211 akarják tartani_v211, amit bejelentettek?\n
# P: {'210': '210', '211': '211'}
# V: {'210': '210', '211': '211'}
# Irrel: []
#
# False neg 212
# A történelemben eddig elő_p212 nem fordult_v212 feladatok elé kerültünk, és ennek is viseljük gondokat okozó terhét.\n
# P: {}
# V: {}
# Irrel: []
#
# Mi nem vagyunk egyértelműen az állami beavatkozásnak az ellenzői.
# P: {}
# V: {}
# Irrel: []
#
# True pos 213
# El_p213 szeretném mondani_v213, sőt, a Kisgazdapárt igényli az állam óvó és védő beavatkozását a gazdaságba, hiszen ma nekünk azzal kell szembenézni, hogy a Coca-Colával kell versenyezni a Szobi szörp családnak.\n
# P: {'213': '212'}
# V: {'213': '212'}
# Irrel: []
#
# True pos 214
# Tudomásunk van arról, hogy ezt a törvényt az Opel meg_p214 kívánja támadni_v214 az Alkotmánybíróság előtt.\n
# P: {'214': '213'}
# V: {'214': '213'}
# Irrel: []
#
# True pos 215
# Én a sportegészségügy, a sportbiztosításnak a maximális híve vagyok, és aki erre áldozza az életét, vagy aki nem az életét áldozza rá és nem sportból, a sport eredményéből akar megélni, hanem csak egészséges ember akar lenni, annak is meg_p215 kell adni_v215 az esélyt, hogy ellenőrzötten, felügyelet mellett és erről a biztosítás mellett is eredményesen tevékenykedhessen.\n
# P: {'215': '215'}
# V: {'215': '215'}
# Irrel: ['214', '214']
#
# True pos 216
# True pos 217
# True pos 218
# True pos 219
# Mert ha csak arra hegyezzük ki a kérdést, hogy le_p216 kell lőni_v216, azt meg_p217 lehet csinálni_v217: el_p218 lehet ejteni_v218 a vadat teljesen titokban, haza_p219 lehet vinni_v219, lehet hasznosítani.\n
# P: {'216': '217', '217': '218', '218': '219', '219': '220'}
# V: {'216': '217', '217': '218', '218': '219', '219': '220'}
# Irrel: ['216', '216']
# True pos 220
# True pos 221
# True pos 222
# Az önkormányzat létrejöttétől eltelt időt azonban ki_p220 kell értékelni_v220 és meg_p221 kell nézni_v221, hogy az a törvény, amely jelenleg szabályozza az önkormányzatok működését, mennyiben állja ki a gyakorlat próbáját, és meg_p222 kell találni_v222 azokat a pontokat, ahol kisebb-nagyobb változásokkal a rendszer működtethető.\n
# P: {'220': '221', '221': '222', '222': '224'}
# V: {'220': '221', '221': '222', '222': '224'}
# Irrel: ['223', '223']
#
# False neg 223
# Ugyanakkor rá_p223 kell arra mutatnom_v223, hogy - a háromoldalú tárgyalásokat is beleszámítva, amelyek közismerten 1989-ben történtek - most már nyolc éve folyik az egész jogrendünk átalakítása, és bizony megítélésem szerint ennek a nyolc évnek bőségesen elegendőnek kellett volna lennie ahhoz, hogy egy új büntetőkódex kerüljön megalkotásra.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 224
# True pos 225
# Emberarcúvá kell formálni s meg_p224 kell nemesíteni_v224 az ember tágabb környezetét, és meg_p225 kell teremtenie_v225 az élelmiszereket és egyéb anyagokat, amelyekre az emberiségnek szüksége van.\n
# P: {'224': '225', '225': '226'}
# V: {'224': '225', '225': '226'}
# Irrel: []
#
# False neg 227
# False neg 228
# True pos 226
# Most közlöm önnel, az eddigi 50 százalékos fogyasztásiadó-visszatérítés, ami a gázolajba be_p226 volt építve_v226, most 70 százalékosra emelkedett fel 1996. január 1-jétől; gépek beszerzéséhez és vásárlásához 25 százalék vissza_p227 nem térítendő_v227 támogatást biztosítunk; beruházásokhoz, építményekhez fix összegű támogatást adunk, ami négyzetméterenként négyezertől nyolcezer forintig terjedhet, és ez - még egyszer mondom - vissza_p228 nem térítendő_v228 támogatás.\n
# P: {'226': '227'}
# V: {'226': '227'}
# Irrel: ['228', '228']
#
#
# P: {}
# V: {}
# Irrel: []
#
# 235
# [179, 5, 7, 44]

# %%
# precision:
precision = true_pos / (true_pos + false_pos)
print("Precision: %.4f"%precision)

# recall:
recall = true_pos / (true_pos + false_neg)
print("Recall: %.4f"%recall)

# F1
print("F1: %.4f"%(2 * precision * recall / (precision + recall)))

# accuracy:
print("Accuracy: %.4f"%((true_pos + true_neg) / preverb_count))
# Out:
# Precision: 0.9730
# Recall: 0.8072
# F1: 0.8824
# Accuracy: 0.7957

# %% [markdown]
# ## Step 7: Evaluate the baseline algorithms

# %%
# !cat preverb_output.tsv | python old_connect_prev.py > baseline_output.tsv

# %%
# Basically same procedure as above, debug lines removed, wrapped in a function,
# abstraction over target field name

PREVERB_COUNT, TRUE_POS, FALSE_POS, TRUE_NEG, FALSE_NEG = 0, 1, 2, 3, 4

def evaluate_target_column(input_file_name, target_col_name):
    preverb_count, true_pos, false_pos, true_neg, false_neg = 0, 0, 0, 0, 0

    with open(input_file_name, encoding='utf-8') as infile:
        header = next(infile)
        Word.features = header.strip().split('\t')

        p_testids = {}
        v_testids = {}
        irrelevant_previds = []

        for n, token in enumerate(infile):
            if token.strip() == '':
                for p_testid, p_target_id in p_testids.items():
                    if (p_target_id in irrelevant_previds or  # \i is connected to a non-annotated verb
                        p_testid not in v_testids or          # \i is not connected to any annotated verbs
                        v_testids[p_testid] != p_target_id):  # \i is not connected to |i, but some other |j
                        false_pos += 1
                    else: 
                        true_pos += 1
                p_testids = {}
                v_testids = {}
                irrelevant_previds = []
                continue

            token = Word(token.strip('\n').split('\t'))
            target_id = getattr(token, target_col_name)
            
            if token.testid == '.':
                if target_id not in ('.', ''):
                    irrelevant_previds.append(target_id)
                continue

            if token.testid == 'p0':
                preverb_count += 1
                if target_id in ('.',''):
                    true_neg += 1    # not connected, OK
                else:
                    false_pos += 1   # preverb annotated as \0 connected to anything
                continue

            if token.testid[0] == 'p':
                preverb_count += 1
                if target_id in ('.',''):
                    false_neg += 1   # preverb annotated as \1 etc. should have been connected
                elif token.testid[1:] in p_testids and p_testids[token.testid[1:]] != target_id:
                    false_pos += 1   # previd does not match preverb with the same annotation
                else:
                    p_testids[token.testid[1:]] = target_id
                continue

            if token.testid[0] == 'v' and target_id not in ('.',''):
                v_testids[token.testid[1:]] = target_id
    
    return (preverb_count, true_pos, false_pos, true_neg, false_neg)

def calculate_metrics(results):
    # precision:
    precision = results[TRUE_POS] / (results[TRUE_POS] + results[FALSE_POS])
    print("Precision: %.4f"%precision)

    # recall:
    recall = results[TRUE_POS] / (results[TRUE_POS] + results[FALSE_NEG])
    print("Recall: %.4f"%recall)

    # F1
    print("F1: %.4f"%(2 * precision * recall / (precision + recall)))

    # accuracy:
    print("Accuracy: %.4f"%((results[TRUE_POS] + results[TRUE_NEG]) / results[PREVERB_COUNT]))

print("Evaluate old connect_prev baseline")

results = evaluate_target_column('baseline_output.tsv', 'prevold')
print(results)
assert results[PREVERB_COUNT] == sum([results[TRUE_POS], 
                                      results[FALSE_POS],
                                      results[TRUE_NEG],
                                      results[FALSE_NEG]]) # debug
calculate_metrics(results)
print()

print("Evaluate connect closest baseline")
results = evaluate_target_column('baseline_output.tsv', 'prevclosest')
print(results)
assert results[PREVERB_COUNT] == sum([results[TRUE_POS], 
                                      results[FALSE_POS],
                                      results[TRUE_NEG],
                                      results[FALSE_NEG]]) # debug
calculate_metrics(results)
print()
# Out:
# Evaluate old connect_prev baseline
# (235, 185, 9, 7, 34)
# Precision: 0.9536
# Recall: 0.8447
# F1: 0.8959
# Accuracy: 0.8170
#
# Evaluate connect closest baseline
# (235, 172, 55, 2, 6)
# Precision: 0.7577
# Recall: 0.9663
# F1: 0.8494
# Accuracy: 0.7404

# %% [markdown]
# ## Step 8: Evaluate Stanza preverb connections

# %%
# !cat validate.txt | python reformat_for_tok.py | docker run -i mtaril/emtsv emstanza-tok > stanzatok_output.txt
# !cat stanzatok_output.txt | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > stanzaparse_output.txt

# %%
from more_itertools import split_at

with open('stanzaparse_output.txt', encoding='utf-8') as infile:
    with open('stanzaprev.txt', 'w', encoding='utf-8') as outfile:
        header = next(infile)
        Word.features = header.strip().split('\t') + ['stanzaid']
        outfile.write(Word.header() + '\n')
        lines = infile.read().split('\n')
        sentences = list(split_at(lines, lambda x: x == ''))
        for s in sentences:
            words = [Word(token.split('\t') + ['.']) for token in s]
            for w in words:
                if w.deprel == 'compound:preverb':
                    w.stanzaid = w.head
                    words[int(w.head) - 1].stanzaid = w.head
            for w in words:
                outfile.write(str(w) + '\n')
            outfile.write('\n')

# %%
results = evaluate_target_column("stanzaprev.txt", 'stanzaid')
print(results)
assert results[PREVERB_COUNT] == sum([results[TRUE_POS], 
                                      results[FALSE_POS],
                                      results[TRUE_NEG],
                                      results[FALSE_NEG]]) # debug
calculate_metrics(results)
print()
# Out:
# (235, 180, 25, 1, 29)
# Precision: 0.8780
# Recall: 0.8612
# F1: 0.8696
# Accuracy: 0.7702

# %% [markdown]
# ## Step 9: Generalising evaluation workflow

# %%
test_set_name = 'validate'
test_set_raw = test_set_name + '.txt'
test_set_reformatted = test_set_name + '_reformat.txt'
test_set_emtok_output = test_set_name + '_emtok_output.tsv'
test_set_empos_output = test_set_name + '_empos_output.tsv'
test_set_preverb_output = test_set_name + '_preverb_output.tsv'
test_set_baseline_output = test_set_name + '_baseline_output.tsv'

test_set_stanza_tok_output = test_set_name + '_stanzatok_output.tsv'
test_set_stanza_parse_output = test_set_name + '_stanzaparse_output.tsv'
test_set_stanza_ids = test_set_name + '_stanzaids.tsv'

# %%
# !cat {test_set_raw} | python reformat_for_tok.py > {test_set_reformatted}
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv tok > {test_set_emtok_output}
# !cat {test_set_emtok_output} | python label_to_column.py | docker run -i mtaril/emtsv morph,pos > {test_set_empos_output}
# !cat {test_set_empos_output} | python ../preverb > {test_set_preverb_output}
# !cat {test_set_preverb_output} | python old_connect_prev.py > {test_set_baseline_output}

# %%
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv emstanza-tok > {test_set_stanza_tok_output}
# !cat {test_set_stanza_tok_output} | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > {test_set_stanza_parse_output}
# !cat {test_set_stanza_parse_output} | python add_stanzaid.py > {test_set_stanza_ids}

# %%
print("emPreverb results")
results = evaluate_target_column(test_set_baseline_output, 'previd')
calculate_metrics(results)
print()

print("old connect_prev (max2) results")
results = evaluate_target_column(test_set_baseline_output, 'prevold')
calculate_metrics(results)
print()

print("closest verb baseline results")
results = evaluate_target_column(test_set_baseline_output, 'prevclosest')
calculate_metrics(results)
print()

print("stanza results")
results = evaluate_target_column(test_set_stanza_ids, 'stanzaid')
calculate_metrics(results)
print()
# Out:
# emPreverb results
# Precision: 0.9728
# Recall: 0.8027
# F1: 0.8796
# Accuracy: 0.7915
#
# old connect_prev (max2) results
# Precision: 0.9534
# Recall: 0.8402
# F1: 0.8932
# Accuracy: 0.8128
#
# closest verb baseline results
# Precision: 0.7689
# Recall: 0.9505
# F1: 0.8501
# Accuracy: 0.7404
#
# stanza results
# Precision: 0.8780
# Recall: 0.8612
# F1: 0.8696
# Accuracy: 0.7702

# %% [markdown]
# ## Step 10: Evaluation on general (easy) dataset

# %%
test_set_name = 'gold500_test'
test_set_raw = test_set_name + '.txt'
test_set_reformatted = test_set_name + '_reformat.txt'
test_set_emtok_output = test_set_name + '_emtok_output.tsv'
test_set_empos_output = test_set_name + '_empos_output.tsv'
test_set_preverb_output = test_set_name + '_preverb_output.tsv'
test_set_baseline_output = test_set_name + '_baseline_output.tsv'

test_set_stanza_tok_output = test_set_name + '_stanzatok_output.tsv'
test_set_stanza_parse_output = test_set_name + '_stanzaparse_output.tsv'
test_set_stanza_ids = test_set_name + '_stanzaids.tsv'

# !cat {test_set_raw} | python reformat_for_tok.py > {test_set_reformatted}
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv tok > {test_set_emtok_output}
# !cat {test_set_emtok_output} | python label_to_column.py | docker run -i mtaril/emtsv morph,pos > {test_set_empos_output}
# !cat {test_set_empos_output} | python ../preverb > {test_set_preverb_output}
# !cat {test_set_preverb_output} | python old_connect_prev.py > {test_set_baseline_output}

# !cat {test_set_reformatted} | docker run -i mtaril/emtsv emstanza-tok > {test_set_stanza_tok_output}
# !cat {test_set_stanza_tok_output} | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > {test_set_stanza_parse_output}
# !cat {test_set_stanza_parse_output} | python add_stanzaid.py > {test_set_stanza_ids}

# %%
print("emPreverb results")
results = evaluate_target_column(test_set_baseline_output, 'previd')
calculate_metrics(results)
print()

print("old connect_prev (max2) results")
results = evaluate_target_column(test_set_baseline_output, 'prevold')
calculate_metrics(results)
print()

print("closest verb baseline results")
results = evaluate_target_column(test_set_baseline_output, 'prevclosest')
calculate_metrics(results)
print()

print("stanza results")
results = evaluate_target_column(test_set_stanza_ids, 'stanzaid')
calculate_metrics(results)
print()
# Out:
# emPreverb results
# Precision: 0.9979
# Recall: 0.9539
# F1: 0.9754
# Accuracy: 0.9520
#
# old connect_prev (max2) results
# Precision: 0.9794
# Recall: 0.9694
# F1: 0.9744
# Accuracy: 0.9500
#
# closest verb baseline results
# Precision: 0.9656
# Recall: 0.9876
# F1: 0.9765
# Accuracy: 0.9540
#
# stanza results
# Precision: 0.9604
# Recall: 0.9046
# F1: 0.9316
# Accuracy: 0.8720
